# %% [markdown]
# ## Interpreter

# %% [markdown]
# Python is an interpreted language which can be used in two ways:
#
# "Interactively": when you use it as an “advanced calculator” executing one command at a time. To start Python in this mode, execute python on the command line:

# %%
2 + 2
# Out:
# 4

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# "Scripting" Mode: executing a series of “commands” saved in text file, usually with a .py extension after the name of your file:

# %%
python my_script.py
# Out:
#   Cell In[10], line 1
#     python my_script.py
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Introduction to variables in Python

# %% [markdown]
# ### Assigning values to variables
# One of the most basic things we can do in Python is assign values to variables:

# %%
text = "Data Carpentry"  # An example of assigning a value to a new text variable,
                         # also known as a string data type in Python
number = 42              # An example of assigning a numeric value, or an integer data type
pi_value = 3.1415        # An example of assigning a floating point value (the float data type)

# %% [markdown]
# Here we’ve assigned data to the variables `text`, `number` and `pi_value`, using the assignment operator `=`. To review the value of a variable, we can type the name of the variable into the interpreter and press `Return`:

# %%
text
# Out:
# 'Data Carpentry'

# %% [markdown]
# Everything in Python has a type. To get the type of something, we can pass it to the built-in function type:

# %%
# Type of the text object
type(text)
# Out:
# str

# %%
# Type of the number object
type(number)
# Out:
# int

# %%
# Type of the pi_value object
type(pi_value)

# %% [markdown]
# The variable `text` is of type `str`, short for “string”. Strings hold sequences of characters, which can be letters, numbers, punctuation or more exotic forms of text (even emoji!).
#
# We can also see the value of something using another built-in function, `print`:

# %%
print(text)
# Out:
# Data Carpentry

# %%
print(number)
# Out:
# 42

# %% [markdown]
# This may seem redundant, but in fact it’s the only way to display output in a script.

# %% [markdown]
# Tip: `print` and `type` are built-in functions in Python.

# %% [markdown]
# ### Operators
# We can perform mathematical calculations in Python using the basic operators +, -, /, *, %:

# %%
2 + 2  # Addition
# Out:
# 4

# %%
6 * 7  # Multiplication
# Out:
# 42

# %%
2 ** 16  # Power
# Out:
# 65536

# %%
13 % 5  # Modulo
# Out:
# 3

# %% [markdown]
# We can also use comparison and logic operators: <, >, ==, !=, <=, >= and statements of identity such as and, or, not. The data type returned by this is called a boolean.

# %%
3 > 4
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
True and False
# Out:
# False

# %% [markdown]
# ------------------------------------------------------
# # SLIDES
# ------------------------------------------------------

# %% [markdown]
# # Getting help

# %%
x = 20
help(x)
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(...)
#  |      Ceiling of an Integral returns itself.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(...)
#  |      Flooring an Integral returns itself.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Default object formatter.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __index__(self, /)
#  |      Return self converted to an integer, if self is suitable for use as an index into a list.
#  |
#  |  __int__(self, /)
#  |      int(self)
#  |
#  |  __invert__(self, /)
#  |      ~self
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lshift__(self, value, /)
#  |      Return self<<value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __neg__(self, /)
#  |      -self
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __pos__(self, /)
#  |      +self
#  |
#  |  __pow__(self, value, mod=None, /)
#  |      Return pow(self, value, mod).
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __rdivmod__(self, value, /)
#  |      Return divmod(value, self).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rfloordiv__(self, value, /)
#  |      Return value//self.
#  |
#  |  __rlshift__(self, value, /)
#  |      Return value<<self.
#  |
#  |  __rmod__(self, value, /)
#  |      Return value%self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __round__(...)
#  |      Rounding an Integral returns itself.
#  |
#  |      Rounding with an ndigits argument also returns an integer.
#  |
#  |  __rpow__(self, value, mod=None, /)
#  |      Return pow(value, self, mod).
#  |
#  |  __rrshift__(self, value, /)
#  |      Return value>>self.
#  |
#  |  __rshift__(self, value, /)
#  |      Return self>>value.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rtruediv__(self, value, /)
#  |      Return value/self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(self, /)
#  |      Returns size in memory, in bytes.
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __truediv__(self, value, /)
#  |      Return self/value.
#  |
#  |  __trunc__(...)
#  |      Truncating an Integral returns itself.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  as_integer_ratio(self, /)
#  |      Return integer ratio.
#  |
#  |      Return a pair of integers, whose ratio is exactly equal to the original int
#  |      and with a positive denominator.
#  |
#  |      >>> (10).as_integer_ratio()
#  |      (10, 1)
#  |      >>> (-10).as_integer_ratio()
#  |      (-10, 1)
#  |      >>> (0).as_integer_ratio()
#  |      (0, 1)
#  |
#  |  bit_count(self, /)
#  |      Number of ones in the binary representation of the absolute value of self.
#  |
#  |      Also known as the population count.
#  |
#  |      >>> bin(13)
#  |      '0b1101'
#  |      >>> (13).bit_count()
#  |      3
#  |
#  |  bit_length(self, /)
#  |      Number of bits necessary to represent self in binary.
#  |
#  |      >>> bin(37)
#  |      '0b100101'
#  |      >>> (37).bit_length()
#  |      6
#  |
#  |  conjugate(...)
#  |      Returns self, the complex conjugate of any int.
#  |
#  |  to_bytes(self, /, length, byteorder, *, signed=False)
#  |      Return an array of bytes representing an integer.
#  |
#  |      length
#  |        Length of bytes object to use.  An OverflowError is raised if the
#  |        integer is not representable with the given number of bytes.
#  |      byteorder
#  |        The byte order used to represent the integer.  If byteorder is 'big',
#  |        the most significant byte is at the beginning of the byte array.  If
#  |        byteorder is 'little', the most significant byte is at the end of the
#  |        byte array.  To request the native byte order of the host system, use
#  |        `sys.byteorder' as the byte order value.
#  |      signed
#  |        Determines whether two's complement is used to represent the integer.
#  |        If signed is False and a negative integer is given, an OverflowError
#  |        is raised.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_bytes(bytes, byteorder, *, signed=False) from builtins.type
#  |      Return the integer represented by the given array of bytes.
#  |
#  |      bytes
#  |        Holds the array of bytes to convert.  The argument must either
#  |        support the buffer protocol or be an iterable object producing bytes.
#  |        Bytes and bytearray are examples of built-in objects that support the
#  |        buffer protocol.
#  |      byteorder
#  |        The byte order used to represent the integer.  If byteorder is 'big',
#  |        the most significant byte is at the beginning of the byte array.  If
#  |        byteorder is 'little', the most significant byte is at the end of the
#  |        byte array.  To request the native byte order of the host system, use
#  |        `sys.byteorder' as the byte order value.
#  |      signed
#  |        Indicates whether two's complement is used to represent the integer.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  denominator
#  |      the denominator of a rational number in lowest terms
#  |
#  |  imag
#  |      the imaginary part of a complex number
#  |
#  |  numerator
#  |      the numerator of a rational number in lowest terms
#  |
#  |  real
#  |      the real part of a complex number

# %%
# Display all of the available methods (functions) that are built into a data object
dir(text)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %% [markdown]
# ------------------------------------------------------
# # SLIDES
# ------------------------------------------------------

# %% [markdown]
# ## Sequences: Lists and Tuples

# %% [markdown]
# ### Lists
# Lists are a common data structure to hold an ordered sequence of elements. Each element can be accessed by an index. Note that Python indexes start with 0 instead of 1:

# %%
numbers = [1, 2, 3]
numbers[0]
# Out:
# 1

# %%
# Indentation is very important in Python.
for num in numbers:
    print(num)
# Out:
# 1
# 2
# 3

# %% [markdown]
# To add elements to the end of a list, we can use the append method.

# %%
numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# To find out what methods are available for an object, we can use the built-in help command:

# %%
help(numbers)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the list.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(self, /)
#  |      Return the size of the list in memory, in bytes.
#  |
#  |  append(self, object, /)
#  |      Append object to the end of the list.
#  |
#  |  clear(self, /)
#  |      Remove all items from list.
#  |
#  |  copy(self, /)
#  |      Return a shallow copy of the list.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  extend(self, iterable, /)
#  |      Extend list by appending elements from the iterable.
#  |
#  |  index(self, value, start=0, stop=9223372036854775807, /)
#  |      Return first index of value.
#  |
#  |      Raises ValueError if the value is not present.
#  |
#  |  insert(self, index, object, /)
#  |      Insert object before index.
#  |
#  |  pop(self, index=-1, /)
#  |      Remove and return item at index (default last).
#  |
#  |      Raises IndexError if list is empty or index is out of range.
#  |
#  |  remove(self, value, /)
#  |      Remove first occurrence of value.
#  |
#  |      Raises ValueError if the value is not present.
#  |
#  |  reverse(self, /)
#  |      Reverse *IN PLACE*.
#  |
#  |  sort(self, /, *, key=None, reverse=False)
#  |      Sort the list in ascending order and return None.
#  |
#  |      The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
#  |      order of two equal elements is maintained).
#  |
#  |      If a key function is given, apply it once to each list item and sort them,
#  |      ascending or descending, according to their function values.
#  |
#  |      The reverse flag can be set to sort in descending order.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  __class_getitem__(...) from builtins.type
#  |      See PEP 585
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %% [markdown]
# ### Tuples
# A tuple is similar to a list in that it’s an ordered sequence of elements. However, tuples can not be changed once created (they are “immutable”). Tuples are created by placing comma-separated values inside parentheses ().

# %%
# Tuples use parentheses
a_tuple = (1, 2, 3)
another_tuple = ('blue', 'green', 'red')

# Note: lists use square brackets
a_list = [1, 2, 3]

# %% [markdown]
# ---------------------------------
# # CHALLENGE 1
# ---------------------------------

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# A dictionary is a container that holds pairs of objects - keys and values.

# %%
translation = {'one': 'first', 'two': 'second'}
translation['one']
# Out:
# 'first'

# %% [markdown]
# Dictionaries work a lot like lists - except that you index them with keys. You can think about a key as a name or unique identifier for the value it corresponds to.

# %%
rev = {'first': 'one', 'second': 'two'}
rev['first']
# Out:
# 'one'

# %% [markdown]
# To add an item to the dictionary we assign a value to a new key:

# %%
rev['third'] = 'three'
rev
# Out:
# {'first': 'one', 'second': 'two', 'third': 'three'}

# %% [markdown]
# Using for loops with dictionaries is a little more complicated. We can do this in two ways:

# %%
for key, value in rev.items():
    print(key, '->', value)
# Out:
# first -> one
# second -> two
# third -> three

# %%
for key in rev.keys():
    print(key, '->', rev[key])
# Out:
# first -> one
# second -> two
# third -> three

# %% [markdown]
# ---------------------------------
# # CHALLENGE 2
# ---------------------------------

# %% [markdown]
# ## Functions

# %% [markdown]
# Defining a section of code as a function in Python is done using the def keyword. For example a function that takes two arguments and returns their sum can be defined as:

# %%
def add_function(a, b):
    result = a + b
    return result

z = add_function(20, 22)
print(z)
# Out:
# 42

# %% [markdown]
# ## Working With Pandas DataFrames in Python

# %% [markdown]
# ### About Libraries
# A library in Python contains a set of tools (called functions) that perform tasks on our data. Importing a library is like getting a piece of lab equipment out of a storage locker and setting it up on the bench for use in a project. Once a library is set up, it can be used or called to perform the task(s) it was built to do.
#
# One of the best options for working with tabular data in Python is to use the Python Data Analysis Library (a.k.a. Pandas).

# %%
import pandas as pd

# %% [markdown]
# ### Reading CSV Data Using Pandas

# %% [markdown]
# We can use Pandas’ read_csv function to pull the file directly into a DataFrame.
#
# A DataFrame is a 2-dimensional data structure that can store data of different types (including strings, numbers, categories and more) in columns.

# %%
# Note that pd.read_csv is used because we imported pandas as pd
pd.read_csv("tmdb-movies.csv")
# The first column is the index of the DataFrame. 
# The index is used to identify the position of the data, 
# but it is not an actual column of the DataFrame.
# Out:
#            id    imdb_id  popularity    budget    revenue  \
# 0       24452  tt0054033    0.225218     30000          0
# 1       15788  tt0053644    0.114188         0   10000000
# 2        1673  tt0053729    0.267118         0          0
# 3       39890  tt0053719    0.065808         0          0
# 4       11773  tt0054443    0.127219    200000          0
# ...       ...        ...         ...       ...        ...
# 10820  273248  tt3460252    5.898400  44000000  155760117
# 10821  371758  tt3581932    0.112284         0          0
# 10822  321640  tt4299972    0.033378         0          0
# 10823  373977  tt4146128    0.031635         0          0
# 10824  340968  tt2492296    0.249595         0          0
#
#                                       original_title  \
# 0                         The Little Shop of Horrors
# 1                                        The Bellboy
# 2                                   Comanche Station
# 3                               The City of the Dead
# 4                              Village of the Damned
# ...                                              ...
# 10820                              The Hateful Eight
# 10821                       And Then There Were None
# 10822  The Jinx: The Life and Deaths of Robert Durst
# 10823                                Childhood's End
# 10824                                 Show Me a Hero
#
#                                                     cast  \
# 0      Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...
# 1      Jerry Lewis|Alex Gerry|Bob Clayton|Sonnie Sand...
# 2      Randolph Scott|Nancy Gates|Skip Homeier|Dyke J...
# 3      Christopher Lee|Dennis Lotis|Patricia Jessel|T...
# 4      George Sanders|Barbara Shelley|Martin Stephens...
# ...                                                  ...
# 10820  Samuel L. Jackson|Kurt Russell|Jennifer Jason ...
# 10821  Maeve Dermody|Aidan Turner|Charles Dance|Dougl...
# 10822  Robert Durst|Andrew Jarecki|Marc Smerling|Zach...
# 10823  Mike Vogel|Osy Ikhile|Daisy Betts|Georgina Hai...
# 10824  Oscar Isaac|Alfred Molina|Winona Ryder|Catheri...
#
#                                        homepage              director  \
# 0                                           NaN          Roger Corman
# 1                                           NaN           Jerry Lewis
# 2                                           NaN       Budd Boetticher
# 3                                           NaN  John Llewellyn Moxey
# 4                                           NaN            Wolf Rilla
# ...                                         ...                   ...
# 10820               http://thehatefuleight.com/     Quentin Tarantino
# 10821  http://www.bbc.co.uk/programmes/b06v2v52        Craig Viveiros
# 10822                                       NaN        Andrew Jarecki
# 10823                                       NaN           Nick Hurran
# 10824                                       NaN           Paul Haggis
#
#                                                  tagline  ...  \
# 0                      The funniest picture of the year!  ...
# 1      It's a Series of Silly Sequences and One of Je...  ...
# 2               The One-Man War Against The Comancheros!  ...
# 3      300 years old! Human blood keeps them alive fo...  ...
# 4            What Demonic Force Lurks Behind Those Eyes?  ...
# ...                                                  ...  ...
# 10820   No one comes up here without a damn good reason.  ...
# 10821                 Agatha Christie's darkest thriller  ...
# 10822  Four Decades. Three Murders. And One Very Rich...  ...
# 10823                                                NaN  ...
# 10824  How does a politician know he's doing the righ...  ...
#
#                                                 overview runtime  \
# 0      Black comedy about a young man who creates a c...      70
# 1      Stanley is a bellboy at the Fountainbleau Hote...      72
# 2      A man saves a woman who had been kidnapped by ...      73
# 3      A young coed (Nan Barlow) uses her winter vaca...      76
# 4      In a small English village everyone suddenly f...      77
# ...                                                  ...     ...
# 10820  Bounty hunters seek shelter from a raging bliz...     167
# 10821  Ten strangers, drawn away from their normal li...     168
# 10822  Robert Durst, scion of one of New Yorkâ€™s bil...     240
# 10823  After peaceful aliens invade earth, humanity f...     246
# 10824  Mayor Nick Wasicsko took office in 1987 during...     300
#
#                                         genres  \
# 0                                       Comedy
# 1                                Comedy|Family
# 2                               Action|Western
# 3                                       Horror
# 4                       Horror|Science Fiction
# ...                                        ...
# 10820              Crime|Drama|Mystery|Western
# 10821                            Mystery|Drama
# 10822                              Documentary
# 10823  Thriller|TV Movie|Science Fiction|Drama
# 10824                      History|Crime|Drama
#
#                                     production_companies release_date  \
# 0                                Santa Clara Productions      9/14/60
# 1             Paramount Pictures|Jerry Lewis Productions      7/20/60
# 2      Columbia Pictures Corporation|Ranown Pictures ...       3/1/60
# 3                                Vulcan Productions Inc.       9/9/60
# 4                              Metro-Goldwyn-Mayer (MGM)       7/1/60
# ...                                                  ...          ...
# 10820  Double Feature Films|The Weinstein Company|Fil...     12/25/15
# 10821  British Broadcasting Corporation (BBC)|Mammoth...     12/26/15
# 10822  Blumhouse Productions|Hit the Ground Running F...       2/8/15
# 10823                                                NaN     12/14/15
# 10824                                                NaN      8/16/15
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0             23           6.0          1960  2.211890e+05  0.000000e+00
# 1             12           7.0          1960  0.000000e+00  7.372967e+07
# 2             12           6.5          1960  0.000000e+00  0.000000e+00
# 3             13           6.1          1960  0.000000e+00  0.000000e+00
# 4             28           7.0          1960  1.474593e+06  0.000000e+00
# ...          ...           ...           ...           ...           ...
# 10820       2389           7.4          2015  4.047998e+07  1.432992e+08
# 10821         37           7.7          2015  0.000000e+00  0.000000e+00
# 10822         72           8.4          2015  0.000000e+00  0.000000e+00
# 10823         21           6.2          2015  0.000000e+00  0.000000e+00
# 10824         32           7.7          2015  0.000000e+00  0.000000e+00
#
# [10825 rows x 21 columns]

# %% [markdown]
# ------------------------------------------------------
# # SLIDES
# ------------------------------------------------------

# %% [markdown]
# We need to save the data to memory so we can work with it.
# To do that, we need to assign the DataFrame to a variable.

# %%
# Save data to memory
my_data = pd.read_csv("tmdb-movies.csv")

# %%
# View the data object
my_data
# Out:
#            id    imdb_id  popularity    budget    revenue  \
# 0       24452  tt0054033    0.225218     30000          0
# 1       15788  tt0053644    0.114188         0   10000000
# 2        1673  tt0053729    0.267118         0          0
# 3       39890  tt0053719    0.065808         0          0
# 4       11773  tt0054443    0.127219    200000          0
# ...       ...        ...         ...       ...        ...
# 10820  273248  tt3460252    5.898400  44000000  155760117
# 10821  371758  tt3581932    0.112284         0          0
# 10822  321640  tt4299972    0.033378         0          0
# 10823  373977  tt4146128    0.031635         0          0
# 10824  340968  tt2492296    0.249595         0          0
#
#                                       original_title  \
# 0                         The Little Shop of Horrors
# 1                                        The Bellboy
# 2                                   Comanche Station
# 3                               The City of the Dead
# 4                              Village of the Damned
# ...                                              ...
# 10820                              The Hateful Eight
# 10821                       And Then There Were None
# 10822  The Jinx: The Life and Deaths of Robert Durst
# 10823                                Childhood's End
# 10824                                 Show Me a Hero
#
#                                                     cast  \
# 0      Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...
# 1      Jerry Lewis|Alex Gerry|Bob Clayton|Sonnie Sand...
# 2      Randolph Scott|Nancy Gates|Skip Homeier|Dyke J...
# 3      Christopher Lee|Dennis Lotis|Patricia Jessel|T...
# 4      George Sanders|Barbara Shelley|Martin Stephens...
# ...                                                  ...
# 10820  Samuel L. Jackson|Kurt Russell|Jennifer Jason ...
# 10821  Maeve Dermody|Aidan Turner|Charles Dance|Dougl...
# 10822  Robert Durst|Andrew Jarecki|Marc Smerling|Zach...
# 10823  Mike Vogel|Osy Ikhile|Daisy Betts|Georgina Hai...
# 10824  Oscar Isaac|Alfred Molina|Winona Ryder|Catheri...
#
#                                        homepage              director  \
# 0                                           NaN          Roger Corman
# 1                                           NaN           Jerry Lewis
# 2                                           NaN       Budd Boetticher
# 3                                           NaN  John Llewellyn Moxey
# 4                                           NaN            Wolf Rilla
# ...                                         ...                   ...
# 10820               http://thehatefuleight.com/     Quentin Tarantino
# 10821  http://www.bbc.co.uk/programmes/b06v2v52        Craig Viveiros
# 10822                                       NaN        Andrew Jarecki
# 10823                                       NaN           Nick Hurran
# 10824                                       NaN           Paul Haggis
#
#                                                  tagline  ...  \
# 0                      The funniest picture of the year!  ...
# 1      It's a Series of Silly Sequences and One of Je...  ...
# 2               The One-Man War Against The Comancheros!  ...
# 3      300 years old! Human blood keeps them alive fo...  ...
# 4            What Demonic Force Lurks Behind Those Eyes?  ...
# ...                                                  ...  ...
# 10820   No one comes up here without a damn good reason.  ...
# 10821                 Agatha Christie's darkest thriller  ...
# 10822  Four Decades. Three Murders. And One Very Rich...  ...
# 10823                                                NaN  ...
# 10824  How does a politician know he's doing the righ...  ...
#
#                                                 overview runtime  \
# 0      Black comedy about a young man who creates a c...      70
# 1      Stanley is a bellboy at the Fountainbleau Hote...      72
# 2      A man saves a woman who had been kidnapped by ...      73
# 3      A young coed (Nan Barlow) uses her winter vaca...      76
# 4      In a small English village everyone suddenly f...      77
# ...                                                  ...     ...
# 10820  Bounty hunters seek shelter from a raging bliz...     167
# 10821  Ten strangers, drawn away from their normal li...     168
# 10822  Robert Durst, scion of one of New Yorkâ€™s bil...     240
# 10823  After peaceful aliens invade earth, humanity f...     246
# 10824  Mayor Nick Wasicsko took office in 1987 during...     300
#
#                                         genres  \
# 0                                       Comedy
# 1                                Comedy|Family
# 2                               Action|Western
# 3                                       Horror
# 4                       Horror|Science Fiction
# ...                                        ...
# 10820              Crime|Drama|Mystery|Western
# 10821                            Mystery|Drama
# 10822                              Documentary
# 10823  Thriller|TV Movie|Science Fiction|Drama
# 10824                      History|Crime|Drama
#
#                                     production_companies release_date  \
# 0                                Santa Clara Productions      9/14/60
# 1             Paramount Pictures|Jerry Lewis Productions      7/20/60
# 2      Columbia Pictures Corporation|Ranown Pictures ...       3/1/60
# 3                                Vulcan Productions Inc.       9/9/60
# 4                              Metro-Goldwyn-Mayer (MGM)       7/1/60
# ...                                                  ...          ...
# 10820  Double Feature Films|The Weinstein Company|Fil...     12/25/15
# 10821  British Broadcasting Corporation (BBC)|Mammoth...     12/26/15
# 10822  Blumhouse Productions|Hit the Ground Running F...       2/8/15
# 10823                                                NaN     12/14/15
# 10824                                                NaN      8/16/15
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0             23           6.0          1960  2.211890e+05  0.000000e+00
# 1             12           7.0          1960  0.000000e+00  7.372967e+07
# 2             12           6.5          1960  0.000000e+00  0.000000e+00
# 3             13           6.1          1960  0.000000e+00  0.000000e+00
# 4             28           7.0          1960  1.474593e+06  0.000000e+00
# ...          ...           ...           ...           ...           ...
# 10820       2389           7.4          2015  4.047998e+07  1.432992e+08
# 10821         37           7.7          2015  0.000000e+00  0.000000e+00
# 10822         72           8.4          2015  0.000000e+00  0.000000e+00
# 10823         21           6.2          2015  0.000000e+00  0.000000e+00
# 10824         32           7.7          2015  0.000000e+00  0.000000e+00
#
# [10825 rows x 21 columns]

# %%
# View the first few lines
my_data.head()
# Out:
#       id    imdb_id  popularity  budget   revenue              original_title  \
# 0  24452  tt0054033    0.225218   30000         0  The Little Shop of Horrors
# 1  15788  tt0053644    0.114188       0  10000000                 The Bellboy
# 2   1673  tt0053729    0.267118       0         0            Comanche Station
# 3  39890  tt0053719    0.065808       0         0        The City of the Dead
# 4  11773  tt0054443    0.127219  200000         0       Village of the Damned
#
#                                                 cast homepage  \
# 0  Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...      NaN
# 1  Jerry Lewis|Alex Gerry|Bob Clayton|Sonnie Sand...      NaN
# 2  Randolph Scott|Nancy Gates|Skip Homeier|Dyke J...      NaN
# 3  Christopher Lee|Dennis Lotis|Patricia Jessel|T...      NaN
# 4  George Sanders|Barbara Shelley|Martin Stephens...      NaN
#
#                director                                            tagline  \
# 0          Roger Corman                  The funniest picture of the year!
# 1           Jerry Lewis  It's a Series of Silly Sequences and One of Je...
# 2       Budd Boetticher           The One-Man War Against The Comancheros!
# 3  John Llewellyn Moxey  300 years old! Human blood keeps them alive fo...
# 4            Wolf Rilla        What Demonic Force Lurks Behind Those Eyes?
#
#    ...                                           overview runtime  \
# 0  ...  Black comedy about a young man who creates a c...      70
# 1  ...  Stanley is a bellboy at the Fountainbleau Hote...      72
# 2  ...  A man saves a woman who had been kidnapped by ...      73
# 3  ...  A young coed (Nan Barlow) uses her winter vaca...      76
# 4  ...  In a small English village everyone suddenly f...      77
#
#                    genres                               production_companies  \
# 0                  Comedy                            Santa Clara Productions
# 1           Comedy|Family         Paramount Pictures|Jerry Lewis Productions
# 2          Action|Western  Columbia Pictures Corporation|Ranown Pictures ...
# 3                  Horror                            Vulcan Productions Inc.
# 4  Horror|Science Fiction                          Metro-Goldwyn-Mayer (MGM)
#
#   release_date vote_count  vote_average  release_year    budget_adj  \
# 0      9/14/60         23           6.0          1960  2.211890e+05
# 1      7/20/60         12           7.0          1960  0.000000e+00
# 2       3/1/60         12           6.5          1960  0.000000e+00
# 3       9/9/60         13           6.1          1960  0.000000e+00
# 4       7/1/60         28           7.0          1960  1.474593e+06
#
#     revenue_adj
# 0  0.000000e+00
# 1  7.372967e+07
# 2  0.000000e+00
# 3  0.000000e+00
# 4  0.000000e+00
#
# [5 rows x 21 columns]

# %%
# View object type
type(my_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# View shape (dimensions)
my_data.shape
# Out:
# (10825, 21)

# %%
# View data types
my_data.dtypes
# All the values in a single column have the same type.
# Some columns cannot contain fractional values
# The object type represents strings
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
# View info
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10825 entries, 0 to 10824
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10825 non-null  int64
#  1   imdb_id               10815 non-null  object
#  2   popularity            10825 non-null  float64
#  3   budget                10825 non-null  int64
#  4   revenue               10825 non-null  int64
#  5   original_title        10825 non-null  object
#  6   cast                  10749 non-null  object
#  7   homepage              2923 non-null   object
#  8   director              10781 non-null  object
#  9   tagline               8012 non-null   object
#  10  keywords              9338 non-null   object
#  11  overview              10821 non-null  object
#  12  runtime               10825 non-null  int64
#  13  genres                10802 non-null  object
#  14  production_companies  9804 non-null   object
#  15  release_date          10825 non-null  object
#  16  vote_count            10825 non-null  int64
#  17  vote_average          10825 non-null  float64
#  18  release_year          10825 non-null  int64
#  19  budget_adj            10825 non-null  float64
#  20  revenue_adj           10825 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %%
# Calculate summary statistics for all numeric columns
my_data['original_title']

# %%
my_data[my_data['original_title']=='The Bellboy']['original_title'].count()

# %% [markdown]
# There are many ways to summarize and access the data stored in DataFrames, using attributes and methods provided by the DataFrame object.
#
# Attributes are features of an object.
#
# Methods are like functions, but they only work on particular kinds of objects. With a method, we can supply extra information in the parentheses to control behaviour.

# %% [markdown]
# ---------------------------------
# # CHALLENGE 3
# ---------------------------------

# %% [markdown]
# Let’s perform some quick summary statistics to learn more about the data that we’re working with.

# %%
# View columns
my_data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
my_data['director']
# Out:
# 0                Roger Corman
# 1                 Jerry Lewis
# 2             Budd Boetticher
# 3        John Llewellyn Moxey
# 4                  Wolf Rilla
#                  ...
# 10820       Quentin Tarantino
# 10821          Craig Viveiros
# 10822          Andrew Jarecki
# 10823             Nick Hurran
# 10824             Paul Haggis
# Name: director, Length: 10825, dtype: object

# %%
# View unique directors

# Option 1
pd.unique(my_data['director'])
# Out:
# array(['Roger Corman', 'Jerry Lewis', 'Budd Boetticher', ...,
#        'Brett Morgen', 'Charles de Lauzirika', 'Karan Malhotra'],
#       dtype=object)

# %%
# Option 2
director_names = my_data['director']
unique_directors = pd.unique(director_names)
number_unique_directors = len(unique_directors)
print(number_unique_directors)
# Out:
# 5051

# %% [markdown]
# ---------------------------------
# # CHALLENGE 4
# ---------------------------------

# %% [markdown]
# ------------------------------------------------------
# # SLIDES
# ------------------------------------------------------

# %% [markdown]
# ## Groups in Pandas

# %% [markdown]
# We often want to calculate summary statistics grouped by subsets or attributes within fields of our data.
#
# We can calculate basic statistics for all records in a single column using the syntax below:

# %%
my_data['revenue'].describe()

# %% [markdown]
# We can also extract one specific metric if we wish:

# %%
my_data['revenue'].min()
my_data['revenue'].max()
my_data['revenue'].mean()
my_data['revenue'].std()
my_data['revenue'].count()

# %% [markdown]
# But if we want to summarize by one or more variables, we can use Pandas’ `.groupby` method.

# %%
# Group data by director
grouped_data = my_data.groupby('director')

# %%
# Summary statistics for all numeric columns by director
grouped_data.describe()
# Out:
#                               id                                         \
#                            count           mean           std       min
# director
#  FrÃ©dÃ©ric Jardin           1.0   79070.000000           NaN   79070.0
# A. Todd Smith                1.0  370687.000000           NaN  370687.0
# A.R. Murugadoss              1.0   14070.000000           NaN   14070.0
# Aaron Aites                  1.0   36124.000000           NaN   36124.0
# Aaron Blaise|Robert Walker   1.0   10009.000000           NaN   10009.0
# ...                          ...            ...           ...       ...
# Ã‡aÄŸan Irmak                1.0   13393.000000           NaN   13393.0
# Ã‰mile Gaudreault            1.0     321.000000           NaN     321.0
# Ã‰ric Besnard                1.0   52349.000000           NaN   52349.0
# Ã‰tienne Chatiliez           3.0   16637.333333  23387.627548    2029.0
# Ã€lex Pastor|David Pastor    1.0   25769.000000           NaN   25769.0
#
#                                                                    popularity  \
#                                  25%       50%       75%       max      count
# director
#  FrÃ©dÃ©ric Jardin           79070.0   79070.0   79070.0   79070.0        1.0
# A. Todd Smith               370687.0  370687.0  370687.0  370687.0        1.0
# A.R. Murugadoss              14070.0   14070.0   14070.0   14070.0        1.0
# Aaron Aites                  36124.0   36124.0   36124.0   36124.0        1.0
# Aaron Blaise|Robert Walker   10009.0   10009.0   10009.0   10009.0        1.0
# ...                              ...       ...       ...       ...        ...
# Ã‡aÄŸan Irmak                13393.0   13393.0   13393.0   13393.0        1.0
# Ã‰mile Gaudreault              321.0     321.0     321.0     321.0        1.0
# Ã‰ric Besnard                52349.0   52349.0   52349.0   52349.0        1.0
# Ã‰tienne Chatiliez            3150.0    4271.0   23941.5   43612.0        3.0
# Ã€lex Pastor|David Pastor    25769.0   25769.0   25769.0   25769.0        1.0
#
#                                       ...    budget_adj                \
#                                 mean  ...           75%           max
# director                              ...
#  FrÃ©dÃ©ric Jardin          0.434506  ...  2.423495e+06  2.423495e+06
# A. Todd Smith               1.876037  ...  0.000000e+00  0.000000e+00
# A.R. Murugadoss             0.215030  ...  9.216358e+06  9.216358e+06
# Aaron Aites                 0.108700  ...  0.000000e+00  0.000000e+00
# Aaron Blaise|Robert Walker  1.653031  ...  1.185353e+08  1.185353e+08
# ...                              ...  ...           ...           ...
# Ã‡aÄŸan Irmak               0.265008  ...  0.000000e+00  0.000000e+00
# Ã‰mile Gaudreault           0.276911  ...  5.170387e+06  5.170387e+06
# Ã‰ric Besnard               0.081724  ...  0.000000e+00  0.000000e+00
# Ã‰tienne Chatiliez          0.102346  ...  9.562436e+06  1.912487e+07
# Ã€lex Pastor|David Pastor   0.619369  ...  0.000000e+00  0.000000e+00
#
#                            revenue_adj                                   \
#                                  count          mean  std           min
# director
#  FrÃ©dÃ©ric Jardin                 1.0  3.255239e+03  NaN  3.255239e+03
# A. Todd Smith                      1.0  0.000000e+00  NaN  0.000000e+00
# A.R. Murugadoss                    1.0  7.697178e+07  NaN  7.697178e+07
# Aaron Aites                        1.0  0.000000e+00  NaN  0.000000e+00
# Aaron Blaise|Robert Walker         1.0  2.963382e+02  NaN  2.963382e+02
# ...                                ...           ...  ...           ...
# Ã‡aÄŸan Irmak                      1.0  0.000000e+00  NaN  0.000000e+00
# Ã‰mile Gaudreault                  1.0  3.593753e+06  NaN  3.593753e+06
# Ã‰ric Besnard                      1.0  0.000000e+00  NaN  0.000000e+00
# Ã‰tienne Chatiliez                 3.0  0.000000e+00  0.0  0.000000e+00
# Ã€lex Pastor|David Pastor          1.0  5.897584e+06  NaN  5.897584e+06
#
#                                                                       \
#                                      25%           50%           75%
# director
#  FrÃ©dÃ©ric Jardin          3.255239e+03  3.255239e+03  3.255239e+03
# A. Todd Smith               0.000000e+00  0.000000e+00  0.000000e+00
# A.R. Murugadoss             7.697178e+07  7.697178e+07  7.697178e+07
# Aaron Aites                 0.000000e+00  0.000000e+00  0.000000e+00
# Aaron Blaise|Robert Walker  2.963382e+02  2.963382e+02  2.963382e+02
# ...                                  ...           ...           ...
# Ã‡aÄŸan Irmak               0.000000e+00  0.000000e+00  0.000000e+00
# Ã‰mile Gaudreault           3.593753e+06  3.593753e+06  3.593753e+06
# Ã‰ric Besnard               0.000000e+00  0.000000e+00  0.000000e+00
# Ã‰tienne Chatiliez          0.000000e+00  0.000000e+00  0.000000e+00
# Ã€lex Pastor|David Pastor   5.897584e+06  5.897584e+06  5.897584e+06
#
#
#                                      max
# director
#  FrÃ©dÃ©ric Jardin          3.255239e+03
# A. Todd Smith               0.000000e+00
# A.R. Murugadoss             7.697178e+07
# Aaron Aites                 0.000000e+00
# Aaron Blaise|Robert Walker  2.963382e+02
# ...                                  ...
# Ã‡aÄŸan Irmak               0.000000e+00
# Ã‰mile Gaudreault           3.593753e+06
# Ã‰ric Besnard               0.000000e+00
# Ã‰tienne Chatiliez          0.000000e+00
# Ã€lex Pastor|David Pastor   5.897584e+06
#
# [5050 rows x 80 columns]

# %%
# Provide the mean for each numeric column by director
grouped_data.mean(numeric_only=True)
# Out:
#                                        id  popularity       budget  \
# director
#  FrÃ©dÃ©ric Jardin           79070.000000    0.434506    2500000.0
# A. Todd Smith               370687.000000    1.876037          0.0
# A.R. Murugadoss              14070.000000    0.215030    9100000.0
# Aaron Aites                  36124.000000    0.108700          0.0
# Aaron Blaise|Robert Walker   10009.000000    1.653031  100000000.0
# ...                                   ...         ...          ...
# Ã‡aÄŸan Irmak                13393.000000    0.265008          0.0
# Ã‰mile Gaudreault              321.000000    0.276911    4361898.0
# Ã‰ric Besnard                52349.000000    0.081724          0.0
# Ã‰tienne Chatiliez           16637.333333    0.102346    4455000.0
# Ã€lex Pastor|David Pastor    25769.000000    0.619369          0.0
#
#                                revenue     runtime  vote_count  vote_average  \
# director
#  FrÃ©dÃ©ric Jardin              3358.0   98.000000   28.000000           5.9
# A. Todd Smith                      0.0    0.000000   11.000000           5.4
# A.R. Murugadoss             76000000.0  183.000000   53.000000           6.9
# Aaron Aites                        0.0   93.000000   13.000000           6.5
# Aaron Blaise|Robert Walker       250.0   85.000000  753.000000           6.8
# ...                                ...         ...         ...           ...
# Ã‡aÄŸan Irmak                      0.0  108.000000   12.000000           8.2
# Ã‰mile Gaudreault            3031801.0   92.000000   13.000000           5.2
# Ã‰ric Besnard                      0.0  100.000000   10.000000           5.1
# Ã‰tienne Chatiliez                 0.0  101.333333   24.666667           6.7
# Ã€lex Pastor|David Pastor    5802422.0   84.000000  143.000000           5.7
#
#                             release_year    budget_adj   revenue_adj
# director
#  FrÃ©dÃ©ric Jardin           2011.000000  2.423495e+06  3.255239e+03
# A. Todd Smith                2015.000000  0.000000e+00  0.000000e+00
# A.R. Murugadoss              2008.000000  9.216358e+06  7.697178e+07
# Aaron Aites                  2008.000000  0.000000e+00  0.000000e+00
# Aaron Blaise|Robert Walker   2003.000000  1.185353e+08  2.963382e+02
# ...                                  ...           ...           ...
# Ã‡aÄŸan Irmak                2005.000000  0.000000e+00  0.000000e+00
# Ã‰mile Gaudreault            2003.000000  5.170387e+06  3.593753e+06
# Ã‰ric Besnard                2010.000000  0.000000e+00  0.000000e+00
# Ã‰tienne Chatiliez           1994.666667  6.374957e+06  0.000000e+00
# Ã€lex Pastor|David Pastor    2009.000000  0.000000e+00  5.897584e+06
#
# [5050 rows x 10 columns]

# %% [markdown]
# ---------------------------------
# # CHALLENGE 5
# ---------------------------------

# %% [markdown]
# Let’s next count the number of movies for each year. We’ll use `groupby` combined with a `count()` method.

# %%
movie_counts = my_data.groupby('release_year')['id'].count()
print(movie_counts)
# Out:
# release_year
# 1960     32
# 1961     31
# 1962     32
# 1963     34
# 1964     42
# 1965     34
# 1966     46
# 1967     40
# 1968     39
# 1969     31
# 1970     41
# 1971     55
# 1972     40
# 1973     55
# 1974     47
# 1975     43
# 1976     47
# 1977     56
# 1978     65
# 1979     56
# 1980     78
# 1981     82
# 1982     80
# 1983     80
# 1984    104
# 1985    109
# 1986    121
# 1987    125
# 1988    143
# 1989    137
# 1990    132
# 1991    133
# 1992    133
# 1993    178
# 1994    183
# 1995    175
# 1996    203
# 1997    191
# 1998    210
# 1999    222
# 2000    227
# 2001    241
# 2002    265
# 2003    280
# 2004    304
# 2005    364
# 2006    408
# 2007    435
# 2008    496
# 2009    525
# 2010    489
# 2011    539
# 2012    586
# 2013    657
# 2014    697
# 2015    627
# Name: id, dtype: int64

# %% [markdown]
# We can also count just the rows that have the genre "Thriller":

# %%
my_data.groupby('genres')['release_year'].count()['Thriller']
# Out:
# np.int64(91)

# %%
my_data[['genres','release_year']].groupby('release_year').describe()
# Out:
#              genres
#               count unique                             top freq
# release_year
# 1960             32     25                          Horror    3
# 1961             31     26                          Horror    3
# 1962             32     26                           Drama    4
# 1963             34     30                          Horror    3
# 1964             42     38                  Comedy|Romance    5
# 1965             34     32  Action|Adventure|Drama|Western    2
# 1966             46     41                  Action|Western    3
# 1967             40     30            Comedy|Drama|Romance    4
# 1968             39     31                           Drama    4
# 1969             31     26                           Drama    5
# 1970             40     30                          Horror    4
# 1971             55     43                           Drama    4
# 1972             40     33                          Comedy    4
# 1973             55     43                          Horror    3
# 1974             46     40          Comedy|Science Fiction    3
# 1975             43     39                           Drama    3
# 1976             47     40                 Horror|Thriller    3
# 1977             56     47          Horror|Science Fiction    4
# 1978             65     55                          Horror    4
# 1979             56     45                          Comedy    5
# 1980             78     58                   Action|Comedy    5
# 1981             82     62                          Comedy    6
# 1982             80     64                          Comedy    7
# 1983             80     60                          Comedy   10
# 1984            104     86                          Comedy    8
# 1985            109     81                           Drama    9
# 1986            121     86                          Comedy    7
# 1987            125     88                          Comedy    8
# 1988            143     86                           Drama   10
# 1989            136     93                          Comedy   12
# 1990            132     95                    Comedy|Drama    7
# 1991            133     93                           Drama    6
# 1992            133     99                           Drama   10
# 1993            178    113                          Comedy   12
# 1994            183    123                          Comedy   10
# 1995            174    118                          Comedy   12
# 1996            202    117                          Comedy   15
# 1997            191    117                          Comedy   13
# 1998            210    137                    Comedy|Drama   12
# 1999            222    132                          Comedy   18
# 2000            226    132                          Comedy   18
# 2001            240    152                          Comedy   15
# 2002            265    169                    Comedy|Drama   13
# 2003            280    169                          Comedy   17
# 2004            304    178                          Comedy   28
# 2005            363    190                           Drama   24
# 2006            408    204                           Drama   31
# 2007            435    225                          Comedy   34
# 2008            495    231                           Drama   33
# 2009            523    256                          Comedy   43
# 2010            487    244                           Drama   37
# 2011            539    261                           Drama   34
# 2012            582    247                           Drama   58
# 2013            654    245                           Drama   59
# 2014            696    274                           Drama   72
# 2015            625    275                           Drama   58

# %% [markdown]
# ## Quick & Easy Plotting Data Using Pandas

# %% [markdown]
# We can plot our summary stats using Pandas, too.

# %%
# Make sure figures appear inline in Ipython Notebook
import matplotlib.pyplot as plt

# %matplotlib inline
# Create a quick bar chart
movie_counts.plot(kind='bar');
# The ; just removes the object type displayed at the top

# %% [markdown]
# ---------------------------------
# # CHALLENGE 6
# ---------------------------------

# %% [markdown]
# ------------------------------------------------------
# # SLIDES
# ------------------------------------------------------

# %% [markdown]
# ## Indexing and Slicing in Python

# %% [markdown]
# We often want to work with subsets of a DataFrame object. There are different ways to accomplish this including: using labels (column headings), numeric ranges, or specific x,y index locations.

# %% [markdown]
# ### Selecting data using Labels (Column Headings)

# %% [markdown]
# We use square brackets [] to select a subset of a Python object.

# %%
# TIP: use the .head() method we saw earlier to make output shorter
# Method 1: select a 'subset' of the data using the column name
my_data['original_title'].head()

# Method 2: use the column name as an 'attribute'; gives the same output
my_data.original_title.head()
# Out:
# 0    The Little Shop of Horrors
# 1                   The Bellboy
# 2              Comanche Station
# 3          The City of the Dead
# 4         Village of the Damned
# Name: original_title, dtype: object

# %% [markdown]
# We can also create a new object that contains only the data within the `original_title` column as follows:

# %%
# Creates an object, movie_titles, that only contains the `original_title` column
movie_titles = my_data['original_title']

# %%
movie_titles
# Out:
# 0                           The Little Shop of Horrors
# 1                                          The Bellboy
# 2                                     Comanche Station
# 3                                 The City of the Dead
# 4                                Village of the Damned
#                              ...
# 10820                                The Hateful Eight
# 10821                         And Then There Were None
# 10822    The Jinx: The Life and Deaths of Robert Durst
# 10823                                  Childhood's End
# 10824                                   Show Me a Hero
# Name: original_title, Length: 10825, dtype: object

# %% [markdown]
# We can pass a list of column names too, as an index to select columns in that order. This is useful when we need to reorganize our data.

# %%
# Select the director and release_year columns from the DataFrame
my_data[['director', 'release_year']]

# What happens when you flip the order?
my_data[['release_year', 'director']]

# What happens if you ask for a column that doesn't exist?
my_data['rating']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 8
#       5 my_data[['release_year', 'director']]
#       7 # What happens if you ask for a column that doesn't exist?
# ----> 8 my_data['rating']
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'rating'

# %% [markdown]
# ### Extracting Range based Subsets: Slicing

# %% [markdown]
# Python uses 0-based indexing. This means that the first element in an object is located at position 0.

# %%
# Create a list of numbers
a = [1, 2, 3, 4, 5]

# %%
# Indexing: getting a specific element
a[2]
# Out:
# 3

# %%
# Slicing: selecting a set of elements
a[1:3]
# Out:
# [2, 3]

# %% [markdown]
# ---------------------------------
# # CHALLENGE 7
# ---------------------------------

# %% [markdown]
# ## Slicing Subsets of Rows and Columns

# %% [markdown]
# Slicing using the `[]` operator selects a set of rows and/or columns from a DataFrame. To slice out a set of rows, you use the following syntax: `data[start:stop]`.
#
# When slicing in pandas the start bound is included in the output. The stop bound is one step BEYOND the row you want to select. So if you want to select rows 0, 1 and 2 your code would look like this:

# %%
# Select rows 0, 1, 2 (row 3 is not selected)
my_data[0:3]

# Select the first 5 rows (rows 0, 1, 2, 3, 4)
my_data[:5]

# Select the last element in the list
# (the slice starts at the last element, and ends at the end of the list)
my_data[-1:]
# Out:
#            id    imdb_id  popularity  budget  revenue  original_title  \
# 10824  340968  tt2492296    0.249595       0        0  Show Me a Hero
#
#                                                     cast homepage  \
# 10824  Oscar Isaac|Alfred Molina|Winona Ryder|Catheri...      NaN
#
#           director                                            tagline  ...  \
# 10824  Paul Haggis  How does a politician know he's doing the righ...  ...
#
#                                                 overview runtime  \
# 10824  Mayor Nick Wasicsko took office in 1987 during...     300
#
#                     genres production_companies release_date vote_count  \
# 10824  History|Crime|Drama                  NaN      8/16/15         32
#
#        vote_average  release_year  budget_adj  revenue_adj
# 10824           7.7          2015         0.0          0.0
#
# [1 rows x 21 columns]

# %%
my_data[-1:]
# Out:
#            id    imdb_id  popularity  budget  revenue  original_title  \
# 10824  340968  tt2492296    0.249595       0        0  Show Me a Hero
#
#                                                     cast homepage  \
# 10824  Oscar Isaac|Alfred Molina|Winona Ryder|Catheri...      NaN
#
#           director                                            tagline  ...  \
# 10824  Paul Haggis  How does a politician know he's doing the righ...  ...
#
#                                                 overview runtime  \
# 10824  Mayor Nick Wasicsko took office in 1987 during...     300
#
#                     genres production_companies release_date vote_count  \
# 10824  History|Crime|Drama                  NaN      8/16/15         32
#
#        vote_average  release_year  budget_adj  revenue_adj
# 10824           7.7          2015         0.0          0.0
#
# [1 rows x 21 columns]

# %%
my_data[0:3]
# Out:
#       id    imdb_id  popularity  budget   revenue              original_title  \
# 0  24452  tt0054033    0.225218   30000         0  The Little Shop of Horrors
# 1  15788  tt0053644    0.114188       0  10000000                 The Bellboy
# 2   1673  tt0053729    0.267118       0         0            Comanche Station
#
#                                                 cast homepage  \
# 0  Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...      NaN
# 1  Jerry Lewis|Alex Gerry|Bob Clayton|Sonnie Sand...      NaN
# 2  Randolph Scott|Nancy Gates|Skip Homeier|Dyke J...      NaN
#
#           director                                            tagline  ...  \
# 0     Roger Corman                  The funniest picture of the year!  ...
# 1      Jerry Lewis  It's a Series of Silly Sequences and One of Je...  ...
# 2  Budd Boetticher           The One-Man War Against The Comancheros!  ...
#
#                                             overview runtime          genres  \
# 0  Black comedy about a young man who creates a c...      70          Comedy
# 1  Stanley is a bellboy at the Fountainbleau Hote...      72   Comedy|Family
# 2  A man saves a woman who had been kidnapped by ...      73  Action|Western
#
#                                 production_companies release_date vote_count  \
# 0                            Santa Clara Productions      9/14/60         23
# 1         Paramount Pictures|Jerry Lewis Productions      7/20/60         12
# 2  Columbia Pictures Corporation|Ranown Pictures ...       3/1/60         12
#
#    vote_average  release_year     budget_adj   revenue_adj
# 0           6.0          1960  221189.023716  0.000000e+00
# 1           7.0          1960       0.000000  7.372967e+07
# 2           6.5          1960       0.000000  0.000000e+00
#
# [3 rows x 21 columns]

# %%
my_data[:5]
# Out:
#       id    imdb_id  popularity  budget   revenue              original_title  \
# 0  24452  tt0054033    0.225218   30000         0  The Little Shop of Horrors
# 1  15788  tt0053644    0.114188       0  10000000                 The Bellboy
# 2   1673  tt0053729    0.267118       0         0            Comanche Station
# 3  39890  tt0053719    0.065808       0         0        The City of the Dead
# 4  11773  tt0054443    0.127219  200000         0       Village of the Damned
#
#                                                 cast homepage  \
# 0  Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...      NaN
# 1  Jerry Lewis|Alex Gerry|Bob Clayton|Sonnie Sand...      NaN
# 2  Randolph Scott|Nancy Gates|Skip Homeier|Dyke J...      NaN
# 3  Christopher Lee|Dennis Lotis|Patricia Jessel|T...      NaN
# 4  George Sanders|Barbara Shelley|Martin Stephens...      NaN
#
#                director                                            tagline  \
# 0          Roger Corman                  The funniest picture of the year!
# 1           Jerry Lewis  It's a Series of Silly Sequences and One of Je...
# 2       Budd Boetticher           The One-Man War Against The Comancheros!
# 3  John Llewellyn Moxey  300 years old! Human blood keeps them alive fo...
# 4            Wolf Rilla        What Demonic Force Lurks Behind Those Eyes?
#
#    ...                                           overview runtime  \
# 0  ...  Black comedy about a young man who creates a c...      70
# 1  ...  Stanley is a bellboy at the Fountainbleau Hote...      72
# 2  ...  A man saves a woman who had been kidnapped by ...      73
# 3  ...  A young coed (Nan Barlow) uses her winter vaca...      76
# 4  ...  In a small English village everyone suddenly f...      77
#
#                    genres                               production_companies  \
# 0                  Comedy                            Santa Clara Productions
# 1           Comedy|Family         Paramount Pictures|Jerry Lewis Productions
# 2          Action|Western  Columbia Pictures Corporation|Ranown Pictures ...
# 3                  Horror                            Vulcan Productions Inc.
# 4  Horror|Science Fiction                          Metro-Goldwyn-Mayer (MGM)
#
#   release_date vote_count  vote_average  release_year    budget_adj  \
# 0      9/14/60         23           6.0          1960  2.211890e+05
# 1      7/20/60         12           7.0          1960  0.000000e+00
# 2       3/1/60         12           6.5          1960  0.000000e+00
# 3       9/9/60         13           6.1          1960  0.000000e+00
# 4       7/1/60         28           7.0          1960  1.474593e+06
#
#     revenue_adj
# 0  0.000000e+00
# 1  7.372967e+07
# 2  0.000000e+00
# 3  0.000000e+00
# 4  0.000000e+00
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Copying Objects vs Referencing Objects

# %%
# Using the 'copy() method'
true_copy_data = my_data.copy()

# Using the '=' operator
ref_data = my_data

# If you change any values in `ref_data`,
# it will also change in `my_data`.

# %% [markdown]
# ## Subsetting Data using Criteria

# %% [markdown]
# We can select specific ranges of our data in both the row and column directions using either label or integer-based indexing.
#
# `iloc` is primarily an integer-based indexing counting from 0. That is, you specify rows and columns giving a number. Thus, the first row is row 0, the second column is column 1, etc.
#
# `loc` is primarily a label-based indexing where you can refer to rows and columns by their name. E.g., column `year`. Note that integers may be used, but they are interpreted as a label.

# %%
# iloc[row slicing, column slicing]
my_data.iloc[0:3, 1:4]

# This yielded 3 rows of data. When you ask for 0:3, 
# you are actually telling Python to start at index 0 
# and select rows 0, 1, 2 up to but not including 3.
# Out:
#      imdb_id  popularity  budget
# 0  tt0054033    0.225218   30000
# 1  tt0053644    0.114188       0
# 2  tt0053729    0.267118       0

# %%
# loc[row slicing, column slicing]
my_data.loc[0:3, 1:4]
# This gives an error, because pandas can't find 
# columns named "1", "2", "3", or "4".
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 2
#       1 # loc[row slicing, column slicing]
# ----> 2 my_data.loc[0:3, 1:4]
#       3 # This gives an error, because pandas can't find
#       4 # columns named "1", "2", "3", or "4".
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1017 if com.is_null_slice(key):
#    1018     continue
# -> 1020 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1021 # We should never have retval.ndim < self.ndim, as that should
#    1022 #  be handled by the _getitem_lowerdim call above.
#    1023 assert retval.ndim == self.ndim
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1411, in _LocIndexer._getitem_axis(self, key, axis)
#    1409 if isinstance(key, slice):
#    1410     self._validate_key(key, axis)
# -> 1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
#    1413     return self._getbool_axis(key, axis=axis)
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1443, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1440     return obj.copy(deep=False)
#    1442 labels = obj._get_axis(axis)
# -> 1443 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1445 if isinstance(indexer, slice):
#    1446     return self.obj._slice(indexer, axis=axis)
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6662, in Index.slice_indexer(self, start, end, step)
#    6618 def slice_indexer(
#    6619     self,
#    6620     start: Hashable | None = None,
#    6621     end: Hashable | None = None,
#    6622     step: int | None = None,
#    6623 ) -> slice:
#    6624     """
#    6625     Compute the slice indexer for input labels and step.
#    6626
#    (...)
#    6660     slice(1, 3, None)
#    6661     """
# -> 6662     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6664     # return a slice
#    6665     if not is_scalar(start_slice):
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6879, in Index.slice_locs(self, start, end, step)
#    6877 start_slice = None
#    6878 if start is not None:
# -> 6879     start_slice = self.get_slice_bound(start, "left")
#    6880 if start_slice is None:
#    6881     start_slice = 0
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6794, in Index.get_slice_bound(self, label, side)
#    6790 original_label = label
#    6792 # For datetime indices label may be a string that has to be converted
#    6793 # to datetime boundary according to its resolution.
# -> 6794 label = self._maybe_cast_slice_bound(label, side)
#    6796 # we need to look up the label
#    6797 try:
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6727, in Index._maybe_cast_slice_bound(self, label, side)
#    6725 # reject them, if index does not contain label
#    6726 if (is_float(label) or is_integer(label)) and label not in self:
# -> 6727     self._raise_invalid_indexer("slice", label)
#    6729 return label
#
# File ~/Code/tutorial/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:4301, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4299 if reraise is not lib.no_default:
#    4300     raise TypeError(msg) from reraise
# -> 4301 raise TypeError(msg)
#
# TypeError: cannot do slice indexing on Index with these indexers [1] of type int

# %% [markdown]
# When using `loc`, integers can be used, but the integers refer to the index label and not the position. For example, using `loc` and select 1:4 will get a different result than using `iloc` to select rows 1:4.

# %%
my_data.loc[0:3, ['imdb_id', 'popularity', 'budget']]
# We have to use LABELS with LOC.
# But do you see the difference in the number of rows? 
# It extract the rows at index 0,1,2 AND 3, because it's using the
# index as a LABEL, and not using it as a positional argument.

# And remember that the start and stop bounds of loc are included.
# Out:
#      imdb_id  popularity  budget
# 0  tt0054033    0.225218   30000
# 1  tt0053644    0.114188       0
# 2  tt0053729    0.267118       0
# 3  tt0053719    0.065808       0

# %%
# Select all columns for rows of index values 0 and 10
my_data.loc[[0, 10], :]

# With loc, both the start bound and the stop bound are inclusive.
# Out:
#        id    imdb_id  popularity   budget  revenue  \
# 0   24452  tt0054033    0.225218    30000        0
# 10  18973  tt0053716    0.055821  3000000  7100000
#
#                 original_title  \
# 0   The Little Shop of Horrors
# 10                 Cinderfella
#
#                                                  cast homepage       director  \
# 0   Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...      NaN   Roger Corman
# 10  Jerry Lewis|Ed Wynn|Judith Anderson|Henry Silv...      NaN  Frank Tashlin
#
#                               tagline  ...  \
# 0   The funniest picture of the year!  ...
# 10                                NaN  ...
#
#                                              overview runtime          genres  \
# 0   Black comedy about a young man who creates a c...      70          Comedy
# 10  This was Jerry Lewis' answer to the classic Ci...      91  Comedy|Romance
#
#                           production_companies release_date vote_count  \
# 0                      Santa Clara Productions      9/14/60         23
# 10  Paramount Pictures|Jerry Lewis Productions     12/18/60         13
#
#     vote_average  release_year    budget_adj   revenue_adj
# 0            6.0          1960  2.211890e+05  0.000000e+00
# 10           7.2          1960  2.211890e+07  5.234807e+07
#
# [2 rows x 21 columns]

# %%
# What does this do?
my_data.loc[0, ['release_year', 'director', 'budget']]

# Note that labels must be found in the DataFrame or you will get a KeyError.
# Out:
# release_year            1960
# director        Roger Corman
# budget                 30000
# Name: 0, dtype: object

# %%
# What happens when you type the code below?
my_data.loc[[0, 10, 3549], :]

# With loc, both the start bound and the stop bound are inclusive.
# Out:
#          id    imdb_id  popularity   budget   revenue  \
# 0     24452  tt0054033    0.225218    30000         0
# 10    18973  tt0053716    0.055821  3000000   7100000
# 3549  10557  tt0166175    0.238748  3800000  28200000
#
#                   original_title  \
# 0     The Little Shop of Horrors
# 10                   Cinderfella
# 3549                East Is East
#
#                                                    cast homepage  \
# 0     Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...      NaN
# 10    Jerry Lewis|Ed Wynn|Judith Anderson|Henry Silv...      NaN
# 3549  Om Puri|Linda Bassett|Ian Aspinall|Jimi Mistry...      NaN
#
#               director                                            tagline  \
# 0         Roger Corman                  The funniest picture of the year!
# 10       Frank Tashlin                                                NaN
# 3549  Damien O'Donnell  A comedy of families, a chip shop... and a ver...
#
#       ...                                           overview runtime  \
# 0     ...  Black comedy about a young man who creates a c...      70
# 10    ...  This was Jerry Lewis' answer to the classic Ci...      91
# 3549  ...  In 1971 Salford fish-and-chip shop owner Georg...      97
#
#               genres                        production_companies release_date  \
# 0             Comedy                     Santa Clara Productions      9/14/60
# 10    Comedy|Romance  Paramount Pictures|Jerry Lewis Productions     12/18/60
# 3549          Comedy                    BBC|Assassin Films|Film4      5/14/99
#
#      vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0            23           6.0          1960  2.211890e+05  0.000000e+00
# 10           13           7.2          1960  2.211890e+07  5.234807e+07
# 3549         24           6.5          1999  4.974401e+06  3.691529e+07
#
# [3 rows x 21 columns]

# %% [markdown]
# We can also select a specific data value using a row and column location within the DataFrame and iloc indexing:

# %% [markdown]
# Syntax for iloc indexing to finding a specific data element:
#
# `data.iloc[row, column]`

# %% [markdown]
# ## Subsetting Data using Criteria

# %% [markdown]
# We can also select a subset of our data using criteria. Let's select all the movies that were released in 2005.

# %%
my_data[my_data.release_year == 2005]
# Out:
#           id    imdb_id  popularity     budget    revenue  \
# 5002   26985  tt0405615    0.371630    2000000          0
# 5003   13739  tt0448245    0.006440          0          0
# 5004   13933  tt0479113    0.392879          0          0
# 5005   45887  tt0813999    0.201372          0          0
# 5006  168891  tt0818519    0.092724          0          0
# ...      ...        ...         ...        ...        ...
# 5361   17919  tt0461872    0.294572   15000000          0
# 5362     254  tt0360717    1.508329  207000000  550000000
# 5363   19082  tt0367555    0.180425    2000000          0
# 5364   11788  tt0465326    0.270637          0          0
# 5365  124673  tt0452573    0.225647          0          0
#
#                     original_title  \
# 5002      The 12 Dogs of Christmas
# 5003               Quatre Ã©toiles
# 5004                  One Man Band
# 5005               Alive in Joburg
# 5006                   Saw Rebirth
# ...                            ...
# 5361             Human Trafficking
# 5362                     King Kong
# 5363  No Direction Home: Bob Dylan
# 5364                   Elizabeth I
# 5365                  The Triangle
#
#                                                    cast  \
# 5002  Jordan-Claire Green|Tom Kemp|Susan Wood|Adam H...
# 5003  JosÃ© Garcia|Isabelle CarrÃ©|RenÃ©e Le Calm|Fr...
# 5004                                                NaN
# 5005  Dawie Ackermann|Jason Cope|Sharlto Copley|Braa...
# 5006  Whit Anderson|Stan Kirsch|Jeff Shuter|George W...
# ...                                                 ...
# 5361  Mira Sorvino|Donald Sutherland|Robert Carlyle|...
# 5362  Naomi Watts|Jack Black|Adrien Brody|Thomas Kre...
# 5363  Bob Dylan|Allen Ginsberg|Joan Baez|Johnny Cash...
# 5364  Helen Mirren|Jeremy Irons|Patrick Malahide|Tob...
# 5365  Eric Stoltz|Catherine Bell|Lou Diamond Phillip...
#
#                                 homepage                     director  \
# 5002                                 NaN                Kieth Merrill
# 5003                                 NaN            Christian Vincent
# 5004                                 NaN  Mark Andrews|Andrew Jimenez
# 5005                                 NaN               Neill Blomkamp
# 5006                                 NaN     Jeff Shuter|Daniel Viney
# ...                                  ...                          ...
# 5361                                 NaN             Christian Duguay
# 5362                                 NaN                Peter Jackson
# 5363                                 NaN              Martin Scorsese
# 5364  http://www.hbo.com/films/elizabeth                   Tom Hooper
# 5365                                 NaN              Craig R. Baxley
#
#                                                 tagline  ...  \
# 5002                                                NaN  ...
# 5003                                                NaN  ...
# 5004                             Vibrant and Whimsical!  ...
# 5005                                                NaN  ...
# 5006    Somewhere... Somehow... Something went wrong...  ...
# ...                                                 ...  ...
# 5361                                                NaN  ...
# 5362                    The eighth wonder of the world.  ...
# 5363      Bob Dylan. Songwriter. Rocker. Rebel. Legend.  ...
# 5364                                                NaN  ...
# 5365  In the Bermuda Triangle, nothing stays lost fo...  ...
#
#                                                overview runtime  \
# 5002  This holiday tale has all the elements of a cl...       0
# 5003                                 No overview found.       0
# 5004  With one coin to make a wish at the piazza fou...       4
# 5005  A documentary-style short film about the arriv...       6
# 5006  This comic, set in the world of SAW goes back ...       6
# ...                                                 ...     ...
# 5361  When a sixteen-year-old girl from the Ukraine,...     176
# 5362  In 1933 New York, an overly ambitious movie pr...     187
# 5363  A chronicle of Bob Dylan's strange evolution b...     208
# 5364  HBO miniseries about the the public and privat...     223
# 5365  A group of people haunted by their experiences...     240
#
#                               genres  \
# 5002                    Drama|Family
# 5003                          Comedy
# 5004                Animation|Family
# 5005                 Science Fiction
# 5006                             NaN
# ...                              ...
# 5361                           Drama
# 5362          Adventure|Drama|Action
# 5363               Documentary|Music
# 5364                   Drama|History
# 5365  Fantasy|Adventure|Action|Drama
#
#                                    production_companies release_date  \
# 5002                                                NaN      11/1/05
# 5003                                                NaN       1/1/05
# 5004                            Pixar Animation Studios      6/21/05
# 5005                                                NaN       1/1/05
# 5006                                                NaN     10/24/05
# ...                                                 ...          ...
# 5361  Muse Entertainment Enterprises|For Sale Produc...     10/24/05
# 5362  WingNut Films|Universal Pictures|Big Primate P...     12/14/05
# 5363                                                NaN      7/21/05
# 5364    Channel 4 Television|HBO Films|Company Pictures      9/29/05
# 5365  Electric Entertainment|British Broadcasting Co...      12/5/05
#
#      vote_count  vote_average  release_year    budget_adj   revenue_adj
# 5002         11           4.7          2005  2.233127e+06  0.000000e+00
# 5003         15           5.9          2005  0.000000e+00  0.000000e+00
# 5004         70           7.1          2005  0.000000e+00  0.000000e+00
# 5005         13           6.5          2005  0.000000e+00  0.000000e+00
# 5006         24           5.9          2005  0.000000e+00  0.000000e+00
# ...         ...           ...           ...           ...           ...
# 5361         12           7.0          2005  1.674845e+07  0.000000e+00
# 5362       1289           6.4          2005  2.311286e+08  6.141098e+08
# 5363         13           7.0          2005  2.233127e+06  0.000000e+00
# 5364         11           6.7          2005  0.000000e+00  0.000000e+00
# 5365         32           5.4          2005  0.000000e+00  0.000000e+00
#
# [364 rows x 21 columns]

# %% [markdown]
# Or we can select all rows that do not contain the year 2005:

# %%
# Option 1
my_data[my_data != 2005]

# Option 2
my_data[~(my_data == 2005)]
# Out:
#              id    imdb_id  popularity    budget    revenue  \
# 0       24452.0  tt0054033    0.225218     30000          0
# 1       15788.0  tt0053644    0.114188         0   10000000
# 2        1673.0  tt0053729    0.267118         0          0
# 3       39890.0  tt0053719    0.065808         0          0
# 4       11773.0  tt0054443    0.127219    200000          0
# ...         ...        ...         ...       ...        ...
# 10820  273248.0  tt3460252    5.898400  44000000  155760117
# 10821  371758.0  tt3581932    0.112284         0          0
# 10822  321640.0  tt4299972    0.033378         0          0
# 10823  373977.0  tt4146128    0.031635         0          0
# 10824  340968.0  tt2492296    0.249595         0          0
#
#                                       original_title  \
# 0                         The Little Shop of Horrors
# 1                                        The Bellboy
# 2                                   Comanche Station
# 3                               The City of the Dead
# 4                              Village of the Damned
# ...                                              ...
# 10820                              The Hateful Eight
# 10821                       And Then There Were None
# 10822  The Jinx: The Life and Deaths of Robert Durst
# 10823                                Childhood's End
# 10824                                 Show Me a Hero
#
#                                                     cast  \
# 0      Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...
# 1      Jerry Lewis|Alex Gerry|Bob Clayton|Sonnie Sand...
# 2      Randolph Scott|Nancy Gates|Skip Homeier|Dyke J...
# 3      Christopher Lee|Dennis Lotis|Patricia Jessel|T...
# 4      George Sanders|Barbara Shelley|Martin Stephens...
# ...                                                  ...
# 10820  Samuel L. Jackson|Kurt Russell|Jennifer Jason ...
# 10821  Maeve Dermody|Aidan Turner|Charles Dance|Dougl...
# 10822  Robert Durst|Andrew Jarecki|Marc Smerling|Zach...
# 10823  Mike Vogel|Osy Ikhile|Daisy Betts|Georgina Hai...
# 10824  Oscar Isaac|Alfred Molina|Winona Ryder|Catheri...
#
#                                        homepage              director  \
# 0                                           NaN          Roger Corman
# 1                                           NaN           Jerry Lewis
# 2                                           NaN       Budd Boetticher
# 3                                           NaN  John Llewellyn Moxey
# 4                                           NaN            Wolf Rilla
# ...                                         ...                   ...
# 10820               http://thehatefuleight.com/     Quentin Tarantino
# 10821  http://www.bbc.co.uk/programmes/b06v2v52        Craig Viveiros
# 10822                                       NaN        Andrew Jarecki
# 10823                                       NaN           Nick Hurran
# 10824                                       NaN           Paul Haggis
#
#                                                  tagline  ...  \
# 0                      The funniest picture of the year!  ...
# 1      It's a Series of Silly Sequences and One of Je...  ...
# 2               The One-Man War Against The Comancheros!  ...
# 3      300 years old! Human blood keeps them alive fo...  ...
# 4            What Demonic Force Lurks Behind Those Eyes?  ...
# ...                                                  ...  ...
# 10820   No one comes up here without a damn good reason.  ...
# 10821                 Agatha Christie's darkest thriller  ...
# 10822  Four Decades. Three Murders. And One Very Rich...  ...
# 10823                                                NaN  ...
# 10824  How does a politician know he's doing the righ...  ...
#
#                                                 overview runtime  \
# 0      Black comedy about a young man who creates a c...      70
# 1      Stanley is a bellboy at the Fountainbleau Hote...      72
# 2      A man saves a woman who had been kidnapped by ...      73
# 3      A young coed (Nan Barlow) uses her winter vaca...      76
# 4      In a small English village everyone suddenly f...      77
# ...                                                  ...     ...
# 10820  Bounty hunters seek shelter from a raging bliz...     167
# 10821  Ten strangers, drawn away from their normal li...     168
# 10822  Robert Durst, scion of one of New Yorkâ€™s bil...     240
# 10823  After peaceful aliens invade earth, humanity f...     246
# 10824  Mayor Nick Wasicsko took office in 1987 during...     300
#
#                                         genres  \
# 0                                       Comedy
# 1                                Comedy|Family
# 2                               Action|Western
# 3                                       Horror
# 4                       Horror|Science Fiction
# ...                                        ...
# 10820              Crime|Drama|Mystery|Western
# 10821                            Mystery|Drama
# 10822                              Documentary
# 10823  Thriller|TV Movie|Science Fiction|Drama
# 10824                      History|Crime|Drama
#
#                                     production_companies release_date  \
# 0                                Santa Clara Productions      9/14/60
# 1             Paramount Pictures|Jerry Lewis Productions      7/20/60
# 2      Columbia Pictures Corporation|Ranown Pictures ...       3/1/60
# 3                                Vulcan Productions Inc.       9/9/60
# 4                              Metro-Goldwyn-Mayer (MGM)       7/1/60
# ...                                                  ...          ...
# 10820  Double Feature Films|The Weinstein Company|Fil...     12/25/15
# 10821  British Broadcasting Corporation (BBC)|Mammoth...     12/26/15
# 10822  Blumhouse Productions|Hit the Ground Running F...       2/8/15
# 10823                                                NaN     12/14/15
# 10824                                                NaN      8/16/15
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0             23           6.0        1960.0  2.211890e+05  0.000000e+00
# 1             12           7.0        1960.0  0.000000e+00  7.372967e+07
# 2             12           6.5        1960.0  0.000000e+00  0.000000e+00
# 3             13           6.1        1960.0  0.000000e+00  0.000000e+00
# 4             28           7.0        1960.0  1.474593e+06  0.000000e+00
# ...          ...           ...           ...           ...           ...
# 10820       2389           7.4        2015.0  4.047998e+07  1.432992e+08
# 10821         37           7.7        2015.0  0.000000e+00  0.000000e+00
# 10822         72           8.4        2015.0  0.000000e+00  0.000000e+00
# 10823         21           6.2        2015.0  0.000000e+00  0.000000e+00
# 10824         32           7.7        2015.0  0.000000e+00  0.000000e+00
#
# [10825 rows x 21 columns]

# %% [markdown]
# We can define sets of criteria too:

# %%
my_data[(my_data.release_year >= 2000) & (my_data.release_year <= 2005)]
# Out:
#           id    imdb_id  popularity     budget    revenue  \
# 3685   46406  tt0248185    0.069903          0          0
# 3686   13930  tt0248808    0.811101          0          0
# 3687   48617  tt0279079    0.191631          0          0
# 3688   32536  tt0234588    0.029510          0          0
# 3689  197725  tt0219105    0.122405          0          0
# ...      ...        ...         ...        ...        ...
# 5361   17919  tt0461872    0.294572   15000000          0
# 5362     254  tt0360717    1.508329  207000000  550000000
# 5363   19082  tt0367555    0.180425    2000000          0
# 5364   11788  tt0465326    0.270637          0          0
# 5365  124673  tt0452573    0.225647          0          0
#
#                     original_title  \
# 3685               Mission Kashmir
# 3686                 For the Birds
# 3687           Father and Daughter
# 3688                      Rejected
# 3689                    John Henry
# ...                            ...
# 5361             Human Trafficking
# 5362                     King Kong
# 5363  No Direction Home: Bob Dylan
# 5364                   Elizabeth I
# 5365                  The Triangle
#
#                                                    cast  \
# 3685  Sanjay Dutt|Hrithik Roshan|Preity Zinta|Jackie...
# 3686                                    Ralph Eggleston
# 3687                                                NaN
# 3688          Robert May|Don Hertzfeldt|Jennifer Nyholm
# 3689  Alfre Woodard|Tim Hodge|Geoffrey Jones|Dave Mu...
# ...                                                 ...
# 5361  Mira Sorvino|Donald Sutherland|Robert Carlyle|...
# 5362  Naomi Watts|Jack Black|Adrien Brody|Thomas Kre...
# 5363  Bob Dylan|Allen Ginsberg|Joan Baez|Johnny Cash...
# 5364  Helen Mirren|Jeremy Irons|Patrick Malahide|Tob...
# 5365  Eric Stoltz|Catherine Bell|Lou Diamond Phillip...
#
#                                                homepage              director  \
# 3685                                                NaN    Vidhu Vinod Chopra
# 3686  http://www.pixar.com/short_films/Theatrical-Sh...       Ralph Eggleston
# 3687                                                NaN  Michael Dudok de Wit
# 3688                                                NaN        Don Hertzfeldt
# 3689                                                NaN             Mark Henn
# ...                                                 ...                   ...
# 5361                                                NaN      Christian Duguay
# 5362                                                NaN         Peter Jackson
# 5363                                                NaN       Martin Scorsese
# 5364                 http://www.hbo.com/films/elizabeth            Tom Hooper
# 5365                                                NaN       Craig R. Baxley
#
#                                                 tagline  ...  \
# 3685                                                NaN  ...
# 3686                                                NaN  ...
# 3687                        Moved to tears in 8 minutes  ...
# 3688                                                NaN  ...
# 3689                                                NaN  ...
# ...                                                 ...  ...
# 5361                                                NaN  ...
# 5362                    The eighth wonder of the world.  ...
# 5363      Bob Dylan. Songwriter. Rocker. Rebel. Legend.  ...
# 5364                                                NaN  ...
# 5365  In the Bermuda Triangle, nothing stays lost fo...  ...
#
#                                                overview runtime  \
# 3685  A police officer adopts the son and sole survi...       0
# 3686  One by one, a flock of small birds perches on ...       3
# 3687  A father says goodbye to his young daughter. I...       8
# 3688  An animator's commissioned works, rejected bec...       9
# 3689  Disney's retelling of the legend of John Henry...      10
# ...                                                 ...     ...
# 5361  When a sixteen-year-old girl from the Ukraine,...     176
# 5362  In 1933 New York, an overly ambitious movie pr...     187
# 5363  A chronicle of Bob Dylan's strange evolution b...     208
# 5364  HBO miniseries about the the public and privat...     223
# 5365  A group of people haunted by their experiences...     240
#
#                               genres  \
# 3685            Action|Drama|Foreign
# 3686         Animation|Comedy|Family
# 3687                 Animation|Drama
# 3688                       Animation
# 3689    Family|Animation|Music|Drama
# ...                              ...
# 5361                           Drama
# 5362          Adventure|Drama|Action
# 5363               Documentary|Music
# 5364                   Drama|History
# 5365  Fantasy|Adventure|Action|Drama
#
#                                    production_companies release_date  \
# 3685                                                NaN     10/27/00
# 3686                            Pixar Animation Studios      11/1/00
# 3687                          CinÃ©TÃ© Filmproductie BV       1/1/00
# 3688                                       Bitter Films      7/25/00
# 3689                               Walt Disney Pictures      5/27/00
# ...                                                 ...          ...
# 5361  Muse Entertainment Enterprises|For Sale Produc...     10/24/05
# 5362  WingNut Films|Universal Pictures|Big Primate P...     12/14/05
# 5363                                                NaN      7/21/05
# 5364    Channel 4 Television|HBO Films|Company Pictures      9/29/05
# 5365  Electric Entertainment|British Broadcasting Co...      12/5/05
#
#      vote_count  vote_average  release_year    budget_adj   revenue_adj
# 3685         10           5.7          2000  0.000000e+00  0.000000e+00
# 3686        247           7.7          2000  0.000000e+00  0.000000e+00
# 3687         18           6.9          2000  0.000000e+00  0.000000e+00
# 3688         12           7.0          2000  0.000000e+00  0.000000e+00
# 3689         11           7.5          2000  0.000000e+00  0.000000e+00
# ...         ...           ...           ...           ...           ...
# 5361         12           7.0          2005  1.674845e+07  0.000000e+00
# 5362       1289           6.4          2005  2.311286e+08  6.141098e+08
# 5363         13           7.0          2005  2.233127e+06  0.000000e+00
# 5364         11           6.7          2005  0.000000e+00  0.000000e+00
# 5365         32           5.4          2005  0.000000e+00  0.000000e+00
#
# [1681 rows x 21 columns]

# %% [markdown]
# ---------------------------------
# # CHALLENGE 8
# ---------------------------------

# %% [markdown]
# ## Using masks to identify a specific condition

# %% [markdown]
# A mask can be useful to locate where a particular subset of values exist or don’t exist - for example, NaN, or “Not a Number” values. To understand masks, we also need to understand BOOLEAN objects in Python.
#
# Boolean values include `True` or `False`. For example:

# %%
# Set x to 5
x = 5

# %%
# What does the code below return?
x > 5
# Out:
# False

# %%
# How about this?
x == 5
# Out:
# True

# %% [markdown]
# # Missing data

# %%
import pandas as pd
my_data_missing = pd.read_csv("tmdb-movies-missing.csv")

# %% [markdown]
# Let’s try this out. Let’s identify all locations in the data that have null (missing or NaN) data values. We can use the `isnull` method to do this. The `isnull` method will compare each cell with a null value. If an element has a null value, it will be assigned a value of `True` in the output object.

# %%
pd.isnull(my_data_missing)
# Out:
#           id  imdb_id  popularity  budget  revenue  original_title   cast  \
# 0      False    False       False   False    False           False  False
# 1      False    False       False   False    False           False  False
# 2      False    False       False   False    False           False  False
# 3      False    False       False   False    False           False  False
# 4      False    False       False   False    False           False  False
# ...      ...      ...         ...     ...      ...             ...    ...
# 10822  False    False       False   False    False           False  False
# 10823  False    False       False   False    False           False  False
# 10824  False    False       False   False    False           False  False
# 10825  False    False       False   False    False           False  False
# 10826  False    False       False   False    False           False  False
#
#        homepage  director  tagline  ...  overview  runtime  genres  \
# 0          True     False    False  ...     False    False   False
# 1          True     False    False  ...     False    False   False
# 2          True     False    False  ...     False    False   False
# 3          True     False    False  ...     False    False   False
# 4          True     False    False  ...     False    False   False
# ...         ...       ...      ...  ...       ...      ...     ...
# 10822     False     False     True  ...     False    False   False
# 10823      True     False    False  ...     False    False   False
# 10824      True     False     True  ...     False    False   False
# 10825     False     False    False  ...     False    False   False
# 10826     False     False    False  ...     False    False   False
#
#        production_companies  release_date  vote_count  vote_average  \
# 0                     False         False       False         False
# 1                     False         False       False         False
# 2                     False         False       False         False
# 3                     False         False       False         False
# 4                     False         False       False         False
# ...                     ...           ...         ...           ...
# 10822                 False         False       False         False
# 10823                 False         False       False         False
# 10824                 False         False       False         False
# 10825                 False         False       False         False
# 10826                 False         False       False         False
#
#        release_year  budget_adj  revenue_adj
# 0             False       False        False
# 1             False       False        False
# 2             False       False        False
# 3             False       False        False
# 4             False       False        False
# ...             ...         ...          ...
# 10822         False       False        False
# 10823         False       False        False
# 10824         False       False        False
# 10825         False       False        False
# 10826         False       False        False
#
# [10827 rows x 21 columns]

# %% [markdown]
# To select the rows where there are null values, we can use the mask as an index to subset our data as follows:

# %%
# To select just the rows with NaN values, we can use the 'any()' method

my_data_missing[pd.isnull(my_data_missing).any(axis=1)]
# axis=1 means that it checks across each row.
# Out:
#              id    imdb_id  popularity     budget    revenue  \
# 0       23220.0  tt0053677    0.333643        0.0        0.0
# 1        6643.0  tt0054428    0.421043        0.0        0.0
# 2       12617.0  tt0054084    0.232574        0.0        0.0
# 3         966.0  tt0054047    1.872132  2000000.0  4905000.0
# 4       11209.0  tt0053580    0.310398        0.0        0.0
# ...         ...        ...         ...        ...        ...
# 10820  354743.0  tt4116030    0.265010        0.0        0.0
# 10821  293941.0  tt2645188    0.195324        0.0        0.0
# 10822  285840.0  tt3067274    0.203224        0.0        0.0
# 10823  318973.0  tt3962848    0.077252        0.0        0.0
# 10824  321974.0  tt3707114    0.162526        0.0        0.0
#
#                 original_title  \
# 0        The Brides of Dracula
# 1               The Unforgiven
# 2                Midnight Lace
# 3        The Magnificent Seven
# 4                    The Alamo
# ...                        ...
# 10820  Lady Chatterley's Lover
# 10821           The Quiet Hour
# 10822               The Editor
# 10823         Welcome to Leith
# 10824  Janis: Little Girl Blue
#
#                                                     cast  \
# 0      Peter Cushing|Martita Hunt|Yvonne Monlaur|Fred...
# 1      Burt Lancaster|Audrey Hepburn|Audie Murphy|Joh...
# 2      Doris Day|Rex Harrison|John Gavin|Myrna Loy|Ro...
# 3      Yul Brynner|Eli Wallach|Steve McQueen|Charles ...
# 4      John Wayne|Richard Widmark|Laurence Harvey|Fra...
# ...                                                  ...
# 10820  Richard Madden|Holliday Grainger|James Norton|...
# 10821  Dakota Blue Richards|Karl Davies|Jack McMullen...
# 10822  Paz de la Huerta|Samantha Hill|Laurence R. Har...
# 10823                                         Craig Cobb
# 10824  Janis Joplin|Cat Power|D.A. Pennebaker|Dick Ca...
#
#                                        homepage  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 10820  http://www.bbc.co.uk/programmes/b06b4jpw
# 10821                                       NaN
# 10822           http://astron-6.com/editor.html
# 10823                                       NaN
# 10824                                       NaN
#
#                                           director  \
# 0                                   Terence Fisher
# 1                                      John Huston
# 2                                     David Miller
# 3                                     John Sturges
# 4                                       John Wayne
# ...                                            ...
# 10820                                 Jed Mercurio
# 10821                          StÃ©phanie Joalland
# 10822                  Adam Brooks|Matthew Kennedy
# 10823  Christopher K. Walker|Michael Beach Nichols
# 10824                                     Amy Berg
#
#                                                  tagline  ...  \
# 0      He Turned Innocent Beauty Into Unspeakable Hor...  ...
# 1      A NEW TRIUMPH FROM ACADEMY AWARD WINNER JOHN H...  ...
# 2      Even with the arms of her love around her...sh...  ...
# 3      They were seven - And they fought like seven h...  ...
# 4      The Mission That Became a Fortress! The Fortre...  ...
# ...                                                  ...  ...
# 10820                           Love Knows No Boundaries  ...
# 10821                                Time is Running Out  ...
# 10822                                                NaN  ...
# 10823                               Know your neighbors.  ...
# 10824                                                NaN  ...
#
#                                                 overview runtime  \
# 0      A young teacher on her way to a position in Tr...      85
# 1      The neighbors of a frontier family turn on the...     125
# 2      This 1960 thriller, set in London, stars Doris...     110
# 3      An oppressed Mexican peasant village hires sev...     128
# 4      The legendary true story of a small band of so...     167
# ...                                                  ...     ...
# 10820  An early-20th-century tale of love across clas...      89
# 10821  In a remote part of rural, post-apocalyptic En...      85
# 10822  A one-time (and now one-handed) master film ed...      95
# 10823  In September 2012, the tiny prairie town of Le...      85
# 10824  Musician Cat Power narrates this documentary o...     106
#
#                                        genres  \
# 0                                      Horror
# 1                        Action|Drama|Western
# 2                                    Thriller
# 3                    Action|Adventure|Western
# 4      Action|Adventure|Drama|History|Western
# ...                                       ...
# 10820                           Romance|Drama
# 10821          Drama|Science Fiction|Thriller
# 10822                   Mystery|Horror|Comedy
# 10823              Thriller|Crime|Documentary
# 10824                       Documentary|Music
#
#                                     production_companies release_date  \
# 0      Hammer Film Productions|Hotspur Film Productio...       1/1/60
# 1                                      James Productions       1/1/60
# 2      Arwin Productions|Universal International Pict...     10/13/60
# 3              The Mirisch Corporation|Alpha Productions     10/23/60
# 4      United Artists|Batjac Productions|The Alamo Co...     10/24/60
# ...                                                  ...          ...
# 10820          Hartswood Films|Serena Cullen Productions       9/6/15
# 10821                          Vision Films|Frenzy Films       9/7/15
# 10822             Astron-6 Video International|Tele-Film       9/8/15
# 10823  Sundial Pictures|No Weather Productions|The Ci...       9/9/15
# 10824                 Jigsaw Productions|Disarming Films       9/9/15
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0             19           6.6          1960  0.000000e+00  0.000000e+00
# 1             17           4.9          1960  0.000000e+00  0.000000e+00
# 2             10           5.7          1960  0.000000e+00  0.000000e+00
# 3            224           7.0          1960  1.474593e+07  3.616441e+07
# 4             27           6.2          1960  0.000000e+00  0.000000e+00
# ...          ...           ...           ...           ...           ...
# 10820         15           6.3          2015  0.000000e+00  0.000000e+00
# 10821         11           5.3          2015  0.000000e+00  0.000000e+00
# 10822         18           6.0          2015  0.000000e+00  0.000000e+00
# 10823         15           6.7          2015  0.000000e+00  0.000000e+00
# 10824         31           7.5          2015  0.000000e+00  0.000000e+00
#
# [8855 rows x 21 columns]

# %% [markdown]
# We can run `isnull` on a particular column too. What does the code below do?

# %%
# What does this do?
missing_titles = my_data_missing[pd.isnull(my_data_missing['original_title'])]
print(missing_titles)

# We are asking Python to select rows that have a NaN value of title, i.e. missing titles.b
# Out:
#              id    imdb_id  popularity       budget      revenue  \
# 10217  264660.0  tt0470752         NaN   15000000.0   36869414.0
# 10386  273248.0  tt3460252      5.8984   44000000.0  155760117.0
# 10462  262500.0        NaN         NaN  110000000.0  295238201.0
#
#       original_title                                               cast  \
# 10217            NaN  Domhnall Gleeson|Alicia Vikander|Oscar Isaac|S...
# 10386            NaN  Samuel L. Jackson|Kurt Russell|Jennifer Jason ...
# 10462            NaN  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                              homepage           director  \
# 10217                     http://exmachina-movie.com/       Alex Garland
# 10386                     http://thehatefuleight.com/  Quentin Tarantino
# 10462  http://www.thedivergentseries.movie/#insurgent   Robert Schwentke
#
#                                                  tagline  ...  \
# 10217  There is nothing more human than the will to s...  ...
# 10386   No one comes up here without a damn good reason.  ...
# 10462                         One Choice Can Destroy You  ...
#
#                                                 overview runtime  \
# 10217  Caleb, a 26 year old coder at the world's larg...     108
# 10386  Bounty hunters seek shelter from a raging bliz...     167
# 10462  Beatrice Prior must confront her inner demons ...     119
#
#                                    genres  \
# 10217               Drama|Science Fiction
# 10386         Crime|Drama|Mystery|Western
# 10462  Adventure|Science Fiction|Thriller
#
#                                     production_companies release_date  \
# 10217  DNA Films|Universal Pictures International (UP...      1/21/15
# 10386  Double Feature Films|The Weinstein Company|Fil...     12/25/15
# 10462  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 10217       2854           7.6          2015  1.379999e+07  3.391985e+07
# 10386       2389           7.4          2015  4.047998e+07  1.432992e+08
# 10462       2480           6.3          2015  1.012000e+08  2.716190e+08
#
# [3 rows x 21 columns]

# %% [markdown]
# Let's extract the homepages for the movies with missing titles:

# %%
missing_titles['homepage']

# You can visit the homepages to get the movie titles.
# Out:
# 10217                       http://exmachina-movie.com/
# 10386                       http://thehatefuleight.com/
# 10462    http://www.thedivergentseries.movie/#insurgent
# Name: homepage, dtype: object

# %% [markdown]
# ## Checking the format of our data

# %% [markdown]
# The format of individual columns and rows will impact analysis performed on a dataset read into a pandas DataFrame. For example, you can’t perform mathematical calculations on a string (text formatted data).
#
# - Every value has a type.
# - Use the built-in function type to find the type of a value.
# - Types control what operations can be done on values.
# - Strings can be added and multiplied.
# - Strings have a length (but numbers don’t).
# - Must convert numbers to strings or vice versa when operating on them.
# - Can mix integers and floats freely in operations.

# %% [markdown]
# ### Types of Data

# %%
my_data.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
my_data['director'].dtype 

# A type "O" stands for "object", i.e. string/text
# Out:
# dtype('O')

# %%
my_data['id'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Working With Integers and Floats

# %% [markdown]
# If we divide one integer by another, we get a float.

# %%
print(5/9)
# Out:
# 0.5555555555555556

# %% [markdown]
# We can also convert a floating point number to an integer or an integer to floating point number. Notice that Python by default rounds down when it converts from floating point to integer.

# %%
# Convert a to an integer
a = 7.83
int(a)
# Out:
# 7

# %%
# Convert b to a float
b = 7
float(b)
# Out:
# 7.0

# %% [markdown]
# ## Working With Our Movies Data

# %%
# Convert the id field from an integer to a float
my_data['id'] = my_data['id'].astype('float64')
my_data['id'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ---------------------------------
# # CHALLENGE 9
# ---------------------------------

# %% [markdown]
# ## Missing Data Values - NaN

# %% [markdown]
# NaN (Not a Number) values are undefined values that cannot be represented mathematically. pandas, for example, will read an empty cell in a CSV or Excel sheet as NaN.

# %% [markdown]
# NaNs have some desirable properties: if we were to average the `budget` column without replacing our NaNs, Python would know to skip over those cells.

# %%
my_data_missing['budget'].mean()
# Out:
# np.float64(14613318.067990761)

# %% [markdown]
# Dealing with missing data values is always a challenge.
#
# It’s sometimes hard to know why values are missing:
# - Was it because of a data entry error?
# - Or data that someone was unable to collect?
# - Should the value be 0?
#
# We need to know how missing values are represented in the dataset in order to make good decisions. If we’re lucky, we have some metadata that will tell us more about how null values were handled.

# %% [markdown]
# We can figure out how many rows contain NaN values for `popularity`. We can also create a new subset from our data that only contains rows with popularity > 0 (i.e., select meaningful values):

# %%
len(my_data_missing[my_data_missing['popularity'].isna()])

# How many rows have popularity values?
len(my_data_missing[my_data_missing['popularity'] > 0])
# Out:
# 10824

# %%
len(my_data_missing[my_data_missing['popularity'].isna()])
# Out:
# 3

# %%
len(my_data_missing['popularity'])
# Out:
# 10827

# %% [markdown]
# We can replace all `NaN` values with zeroes using the .`fillna()` method (after making a copy of the data so we don’t lose our work):

# %%
df1 = my_data_missing.copy()
# Fill all NaN values with 0
df1['popularity'] = df1['popularity'].fillna(0)

# %% [markdown]
# However NaN and 0 yield different analysis results. The mean value when NaN values are replaced with 0 is different from when NaN values are simply thrown out or ignored.

# %%
df1['popularity'].mean()
# Out:
# np.float64(0.64456639770943)

# %% [markdown]
# We can fill NaN values with any value that we chose. The code below fills all NaN values with a mean for all popularity values.

# %%
df1['popularity'] = df1['popularity'].fillna(df1['popularity'].mean())

# %% [markdown]
# ---------------------------------
# # CHALLENGE 10
# ---------------------------------

# %% [markdown]
# ## Writing Out Data to CSV

# %% [markdown]
# First, let’s reload the data so we’re not mixing up all of our previous manipulations.

# %%
my_data = pd.read_csv("tmdb-movies.csv")

# %% [markdown]
# Let’s drop all the rows that contain missing values. We will use the command `dropna`. By default, `dropna` removes rows that contain missing data for even just one column.

# %%
df_na = my_data.dropna()

# Note: If you want to drop rows with missing values in a specific column:
df_na = my_data.dropna(subset=['popularity'])

# %% [markdown]
# Export a DataFrame in CSV format and save it in the `data_output` directory.

# %%
# Write DataFrame to CSV
df_na.to_csv('movies_complete.csv', index=False)

# %% [markdown]
# ------------------------------------------------------
# # SLIDES
# ------------------------------------------------------

# %% [markdown]
# # Concatenating DataFrames

# %% [markdown]
# We often need to combine data files into a single DataFrame to analyze the data.

# %% [markdown]
# We can use the `concat` function in pandas to append either columns or rows from one DataFrame to another.

# %%
# Read in first 10 lines of table
data_sub = my_data.head(10)

# Grab the last 10 rows
data_sub_last10 = my_data.tail(10)

# Reset the index values to the second dataframe appends properly
data_sub_last10 = data_sub_last10.reset_index(drop=True)

# drop=True option avoids adding new index column with old index values

# %%
data_sub_last10
# Out:
#        id    imdb_id  popularity     budget    revenue  \
# 0  277216  tt1398426    3.202719   28000000  201634991
# 1  206647  tt2379713    6.200282  245000000  880674609
# 2  333873  tt4426954    0.197788          0          0
# 3  281957  tt1663202    9.110700  135000000  532950503
# 4  330037  tt3802576    0.099678          0          0
# 5  273248  tt3460252    5.898400   44000000  155760117
# 6  371758  tt3581932    0.112284          0          0
# 7  321640  tt4299972    0.033378          0          0
# 8  373977  tt4146128    0.031635          0          0
# 9  340968  tt2492296    0.249595          0          0
#
#                                       original_title  \
# 0                             Straight Outta Compton
# 1                                            Spectre
# 2  Keepers of the Covenant: Making Exodus: Gods a...
# 3                                       The Revenant
# 4                                           Brothers
# 5                                  The Hateful Eight
# 6                           And Then There Were None
# 7      The Jinx: The Life and Deaths of Robert Durst
# 8                                    Childhood's End
# 9                                     Show Me a Hero
#
#                                                 cast  \
# 0  O'Shea Jackson Jr.|Corey Hawkins|Jason Mitchel...
# 1  Daniel Craig|Christoph Waltz|LÃ©a Seydoux|Ralp...
# 2  Ridley Scott|Christian Bale|Joel Edgerton|Pete...
# 3  Leonardo DiCaprio|Tom Hardy|Will Poulter|Domhn...
# 4  Akshay Kumar|Sidharth Malhotra|Jackie Shroff|J...
# 5  Samuel L. Jackson|Kurt Russell|Jennifer Jason ...
# 6  Maeve Dermody|Aidan Turner|Charles Dance|Dougl...
# 7  Robert Durst|Andrew Jarecki|Marc Smerling|Zach...
# 8  Mike Vogel|Osy Ikhile|Daisy Betts|Georgina Hai...
# 9  Oscar Isaac|Alfred Molina|Winona Ryder|Catheri...
#
#                                             homepage  \
# 0               http://www.straightouttacompton.com/
# 1        http://www.sonypictures.com/movies/spectre/
# 2                                                NaN
# 3       http://www.foxmovies.com/movies/the-revenant
# 4  http://en.wikipedia.org/wiki/Brothers_(2015_film)
# 5                        http://thehatefuleight.com/
# 6           http://www.bbc.co.uk/programmes/b06v2v52
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                          director  \
# 0                    F. Gary Gray
# 1                      Sam Mendes
# 2            Charles de Lauzirika
# 3  Alejandro GonzÃ¡lez IÃ±Ã¡rritu
# 4                  Karan Malhotra
# 5               Quentin Tarantino
# 6                  Craig Viveiros
# 7                  Andrew Jarecki
# 8                     Nick Hurran
# 9                     Paul Haggis
#
#                                              tagline  ...  \
# 0                                The Story of N.W.A.  ...
# 1                              A Plan No One Escapes  ...
# 2         He defied an empire and changed the world.  ...
# 3    (n. One who has returned, as if from the dead.)  ...
# 4                                Blood Against Blood  ...
# 5   No one comes up here without a damn good reason.  ...
# 6                 Agatha Christie's darkest thriller  ...
# 7  Four Decades. Three Murders. And One Very Rich...  ...
# 8                                                NaN  ...
# 9  How does a politician know he's doing the righ...  ...
#
#                                             overview runtime  \
# 0  In 1987, five young men, using brutally honest...     147
# 1  A cryptic message from Bondâ€™s past sends him...     148
# 2  An in-depth documentary on the making of Ridle...     153
# 3  In the 1820s, a frontiersman, Hugh Glass, sets...     156
# 4  Brothers is an upcoming Hindi film, directed b...     156
# 5  Bounty hunters seek shelter from a raging bliz...     167
# 6  Ten strangers, drawn away from their normal li...     168
# 7  Robert Durst, scion of one of New Yorkâ€™s bil...     240
# 8  After peaceful aliens invade earth, humanity f...     246
# 9  Mayor Nick Wasicsko took office in 1987 during...     300
#
#                                     genres  \
# 0                              Drama|Music
# 1                   Action|Adventure|Crime
# 2                              Documentary
# 3         Western|Drama|Adventure|Thriller
# 4                      Family|Action|Drama
# 5              Crime|Drama|Mystery|Western
# 6                            Mystery|Drama
# 7                              Documentary
# 8  Thriller|TV Movie|Science Fiction|Drama
# 9                      History|Crime|Drama
#
#                                 production_companies release_date vote_count  \
# 0  New Line Cinema|Universal Pictures|Legendary P...      8/13/15        918
# 1                       Columbia Pictures|Danjaq|B24     10/26/15       3254
# 2  20th Century Fox|Lauzirika Motion Picture Company      3/17/15         14
# 3  Regency Enterprises|Appian Way|CatchPlay|Anony...     12/25/15       3929
# 4                                 Dharma Productions      8/14/15         20
# 5  Double Feature Films|The Weinstein Company|Fil...     12/25/15       2389
# 6  British Broadcasting Corporation (BBC)|Mammoth...     12/26/15         37
# 7  Blumhouse Productions|Hit the Ground Running F...       2/8/15         72
# 8                                                NaN     12/14/15         21
# 9                                                NaN      8/16/15         32
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           7.7          2015  2.575999e+07  1.855041e+08
# 1           6.2          2015  2.253999e+08  8.102203e+08
# 2           5.5          2015  0.000000e+00  0.000000e+00
# 3           7.2          2015  1.241999e+08  4.903142e+08
# 4           6.3          2015  0.000000e+00  0.000000e+00
# 5           7.4          2015  4.047998e+07  1.432992e+08
# 6           7.7          2015  0.000000e+00  0.000000e+00
# 7           8.4          2015  0.000000e+00  0.000000e+00
# 8           6.2          2015  0.000000e+00  0.000000e+00
# 9           7.7          2015  0.000000e+00  0.000000e+00
#
# [10 rows x 21 columns]

# %% [markdown]
# When we concatenate DataFrames, we need to specify the axis:
# - `axis=0` will stack the second DataFrame UNDER the first one. Columns need to have the same name and data types.
# - `axis=1` will stack the columns in the second DataFrame to the RIGHT of the first DataFrame. Rows need to be related.

# %%
# Stack the DataFrames on top of each other
vertical_stack = pd.concat([data_sub, data_sub_last10], axis=0)
vertical_stack

# Note that the row indexes for the two dataframes have been repeated.
# Out:
#        id    imdb_id  popularity     budget    revenue  \
# 0   24452  tt0054033    0.225218      30000          0
# 1   15788  tt0053644    0.114188          0   10000000
# 2    1673  tt0053729    0.267118          0          0
# 3   39890  tt0053719    0.065808          0          0
# 4   11773  tt0054443    0.127219     200000          0
# 5   23439  tt0053925    0.323180     270000          0
# 6   23220  tt0053677    0.333643          0          0
# 7   29756  tt0053559    0.110511          0          0
# 8   21240  tt0053699    0.136525          0          0
# 9   37230  tt0054269    0.271858          0          0
# 0  277216  tt1398426    3.202719   28000000  201634991
# 1  206647  tt2379713    6.200282  245000000  880674609
# 2  333873  tt4426954    0.197788          0          0
# 3  281957  tt1663202    9.110700  135000000  532950503
# 4  330037  tt3802576    0.099678          0          0
# 5  273248  tt3460252    5.898400   44000000  155760117
# 6  371758  tt3581932    0.112284          0          0
# 7  321640  tt4299972    0.033378          0          0
# 8  373977  tt4146128    0.031635          0          0
# 9  340968  tt2492296    0.249595          0          0
#
#                                       original_title  \
# 0                         The Little Shop of Horrors
# 1                                        The Bellboy
# 2                                   Comanche Station
# 3                               The City of the Dead
# 4                              Village of the Damned
# 5                                     House of Usher
# 6                              The Brides of Dracula
# 7                                          13 Ghosts
# 8                                 Carry On Constable
# 9                  Saturday Night and Sunday Morning
# 0                             Straight Outta Compton
# 1                                            Spectre
# 2  Keepers of the Covenant: Making Exodus: Gods a...
# 3                                       The Revenant
# 4                                           Brothers
# 5                                  The Hateful Eight
# 6                           And Then There Were None
# 7      The Jinx: The Life and Deaths of Robert Durst
# 8                                    Childhood's End
# 9                                     Show Me a Hero
#
#                                                 cast  \
# 0  Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...
# 1  Jerry Lewis|Alex Gerry|Bob Clayton|Sonnie Sand...
# 2  Randolph Scott|Nancy Gates|Skip Homeier|Dyke J...
# 3  Christopher Lee|Dennis Lotis|Patricia Jessel|T...
# 4  George Sanders|Barbara Shelley|Martin Stephens...
# 5  Vincent Price|Mark Damon|Myrna Fahey|Harry Ell...
# 6  Peter Cushing|Martita Hunt|Yvonne Monlaur|Fred...
# 7  Charles Herbert|Jo Morrow|Martin Milner|Rosema...
# 8  Kenneth Connor|Charles Hawtrey|Sid James|Kenne...
# 9  Albert Finney|Shirley Anne Field|Rachel Robert...
# 0  O'Shea Jackson Jr.|Corey Hawkins|Jason Mitchel...
# 1  Daniel Craig|Christoph Waltz|LÃ©a Seydoux|Ralp...
# 2  Ridley Scott|Christian Bale|Joel Edgerton|Pete...
# 3  Leonardo DiCaprio|Tom Hardy|Will Poulter|Domhn...
# 4  Akshay Kumar|Sidharth Malhotra|Jackie Shroff|J...
# 5  Samuel L. Jackson|Kurt Russell|Jennifer Jason ...
# 6  Maeve Dermody|Aidan Turner|Charles Dance|Dougl...
# 7  Robert Durst|Andrew Jarecki|Marc Smerling|Zach...
# 8  Mike Vogel|Osy Ikhile|Daisy Betts|Georgina Hai...
# 9  Oscar Isaac|Alfred Molina|Winona Ryder|Catheri...
#
#                                             homepage  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 0               http://www.straightouttacompton.com/
# 1        http://www.sonypictures.com/movies/spectre/
# 2                                                NaN
# 3       http://www.foxmovies.com/movies/the-revenant
# 4  http://en.wikipedia.org/wiki/Brothers_(2015_film)
# 5                        http://thehatefuleight.com/
# 6           http://www.bbc.co.uk/programmes/b06v2v52
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                          director  \
# 0                    Roger Corman
# 1                     Jerry Lewis
# 2                 Budd Boetticher
# 3            John Llewellyn Moxey
# 4                      Wolf Rilla
# 5                    Roger Corman
# 6                  Terence Fisher
# 7                  William Castle
# 8                   Gerald Thomas
# 9                     Karel Reisz
# 0                    F. Gary Gray
# 1                      Sam Mendes
# 2            Charles de Lauzirika
# 3  Alejandro GonzÃ¡lez IÃ±Ã¡rritu
# 4                  Karan Malhotra
# 5               Quentin Tarantino
# 6                  Craig Viveiros
# 7                  Andrew Jarecki
# 8                     Nick Hurran
# 9                     Paul Haggis
#
#                                              tagline  ...  \
# 0                  The funniest picture of the year!  ...
# 1  It's a Series of Silly Sequences and One of Je...  ...
# 2           The One-Man War Against The Comancheros!  ...
# 3  300 years old! Human blood keeps them alive fo...  ...
# 4        What Demonic Force Lurks Behind Those Eyes?  ...
# 5  Edgar Allan Poe's demonic tale of The Ungodly....  ...
# 6  He Turned Innocent Beauty Into Unspeakable Hor...  ...
# 7                 IT'S FUN TO BE SCARED BY 13 GHOSTS  ...
# 8  Oh! What a Carry On When that Crazy Bunch Join...  ...
# 9  Saturday night you have your fling at life...a...  ...
# 0                                The Story of N.W.A.  ...
# 1                              A Plan No One Escapes  ...
# 2         He defied an empire and changed the world.  ...
# 3    (n. One who has returned, as if from the dead.)  ...
# 4                                Blood Against Blood  ...
# 5   No one comes up here without a damn good reason.  ...
# 6                 Agatha Christie's darkest thriller  ...
# 7  Four Decades. Three Murders. And One Very Rich...  ...
# 8                                                NaN  ...
# 9  How does a politician know he's doing the righ...  ...
#
#                                             overview runtime  \
# 0  Black comedy about a young man who creates a c...      70
# 1  Stanley is a bellboy at the Fountainbleau Hote...      72
# 2  A man saves a woman who had been kidnapped by ...      73
# 3  A young coed (Nan Barlow) uses her winter vaca...      76
# 4  In a small English village everyone suddenly f...      77
# 5  After a long journey, Philip arrives at the Us...      79
# 6  A young teacher on her way to a position in Tr...      85
# 7  Reclusive Dr. Zorba has died and left his mans...      85
# 8  With a flu epidemic running rife, three new bu...      86
# 9  Arthur, one of Britain's angry young men of th...      89
# 0  In 1987, five young men, using brutally honest...     147
# 1  A cryptic message from Bondâ€™s past sends him...     148
# 2  An in-depth documentary on the making of Ridle...     153
# 3  In the 1820s, a frontiersman, Hugh Glass, sets...     156
# 4  Brothers is an upcoming Hindi film, directed b...     156
# 5  Bounty hunters seek shelter from a raging bliz...     167
# 6  Ten strangers, drawn away from their normal li...     168
# 7  Robert Durst, scion of one of New Yorkâ€™s bil...     240
# 8  After peaceful aliens invade earth, humanity f...     246
# 9  Mayor Nick Wasicsko took office in 1987 during...     300
#
#                                     genres  \
# 0                                   Comedy
# 1                            Comedy|Family
# 2                           Action|Western
# 3                                   Horror
# 4                   Horror|Science Fiction
# 5                          Horror|Thriller
# 6                                   Horror
# 7                                   Horror
# 8                                   Comedy
# 9                                    Drama
# 0                              Drama|Music
# 1                   Action|Adventure|Crime
# 2                              Documentary
# 3         Western|Drama|Adventure|Thriller
# 4                      Family|Action|Drama
# 5              Crime|Drama|Mystery|Western
# 6                            Mystery|Drama
# 7                              Documentary
# 8  Thriller|TV Movie|Science Fiction|Drama
# 9                      History|Crime|Drama
#
#                                 production_companies release_date vote_count  \
# 0                            Santa Clara Productions      9/14/60         23
# 1         Paramount Pictures|Jerry Lewis Productions      7/20/60         12
# 2  Columbia Pictures Corporation|Ranown Pictures ...       3/1/60         12
# 3                            Vulcan Productions Inc.       9/9/60         13
# 4                          Metro-Goldwyn-Mayer (MGM)       7/1/60         28
# 5                             Alta Vista Productions      6/21/60         28
# 6  Hammer Film Productions|Hotspur Film Productio...       1/1/60         19
# 7       Columbia Pictures|William Castle Productions       8/5/60         12
# 8                           Peter Rogers Productions      2/22/60         10
# 9                          Woodfall Film Productions      8/29/60         12
# 0  New Line Cinema|Universal Pictures|Legendary P...      8/13/15        918
# 1                       Columbia Pictures|Danjaq|B24     10/26/15       3254
# 2  20th Century Fox|Lauzirika Motion Picture Company      3/17/15         14
# 3  Regency Enterprises|Appian Way|CatchPlay|Anony...     12/25/15       3929
# 4                                 Dharma Productions      8/14/15         20
# 5  Double Feature Films|The Weinstein Company|Fil...     12/25/15       2389
# 6  British Broadcasting Corporation (BBC)|Mammoth...     12/26/15         37
# 7  Blumhouse Productions|Hit the Ground Running F...       2/8/15         72
# 8                                                NaN     12/14/15         21
# 9                                                NaN      8/16/15         32
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.0          1960  2.211890e+05  0.000000e+00
# 1           7.0          1960  0.000000e+00  7.372967e+07
# 2           6.5          1960  0.000000e+00  0.000000e+00
# 3           6.1          1960  0.000000e+00  0.000000e+00
# 4           7.0          1960  1.474593e+06  0.000000e+00
# 5           5.9          1960  1.990701e+06  0.000000e+00
# 6           6.6          1960  0.000000e+00  0.000000e+00
# 7           5.5          1960  0.000000e+00  0.000000e+00
# 8           6.0          1960  0.000000e+00  0.000000e+00
# 9           5.6          1960  0.000000e+00  0.000000e+00
# 0           7.7          2015  2.575999e+07  1.855041e+08
# 1           6.2          2015  2.253999e+08  8.102203e+08
# 2           5.5          2015  0.000000e+00  0.000000e+00
# 3           7.2          2015  1.241999e+08  4.903142e+08
# 4           6.3          2015  0.000000e+00  0.000000e+00
# 5           7.4          2015  4.047998e+07  1.432992e+08
# 6           7.7          2015  0.000000e+00  0.000000e+00
# 7           8.4          2015  0.000000e+00  0.000000e+00
# 8           6.2          2015  0.000000e+00  0.000000e+00
# 9           7.7          2015  0.000000e+00  0.000000e+00
#
# [20 rows x 21 columns]

# %%
# Reindex the new DataFrame using the reset_index() method
vertical_stack = vertical_stack.reset_index(drop=True)

# %%
vertical_stack
# Out:
#         id    imdb_id  popularity     budget    revenue  \
# 0    24452  tt0054033    0.225218      30000          0
# 1    15788  tt0053644    0.114188          0   10000000
# 2     1673  tt0053729    0.267118          0          0
# 3    39890  tt0053719    0.065808          0          0
# 4    11773  tt0054443    0.127219     200000          0
# 5    23439  tt0053925    0.323180     270000          0
# 6    23220  tt0053677    0.333643          0          0
# 7    29756  tt0053559    0.110511          0          0
# 8    21240  tt0053699    0.136525          0          0
# 9    37230  tt0054269    0.271858          0          0
# 10  277216  tt1398426    3.202719   28000000  201634991
# 11  206647  tt2379713    6.200282  245000000  880674609
# 12  333873  tt4426954    0.197788          0          0
# 13  281957  tt1663202    9.110700  135000000  532950503
# 14  330037  tt3802576    0.099678          0          0
# 15  273248  tt3460252    5.898400   44000000  155760117
# 16  371758  tt3581932    0.112284          0          0
# 17  321640  tt4299972    0.033378          0          0
# 18  373977  tt4146128    0.031635          0          0
# 19  340968  tt2492296    0.249595          0          0
#
#                                        original_title  \
# 0                          The Little Shop of Horrors
# 1                                         The Bellboy
# 2                                    Comanche Station
# 3                                The City of the Dead
# 4                               Village of the Damned
# 5                                      House of Usher
# 6                               The Brides of Dracula
# 7                                           13 Ghosts
# 8                                  Carry On Constable
# 9                   Saturday Night and Sunday Morning
# 10                             Straight Outta Compton
# 11                                            Spectre
# 12  Keepers of the Covenant: Making Exodus: Gods a...
# 13                                       The Revenant
# 14                                           Brothers
# 15                                  The Hateful Eight
# 16                           And Then There Were None
# 17      The Jinx: The Life and Deaths of Robert Durst
# 18                                    Childhood's End
# 19                                     Show Me a Hero
#
#                                                  cast  \
# 0   Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...
# 1   Jerry Lewis|Alex Gerry|Bob Clayton|Sonnie Sand...
# 2   Randolph Scott|Nancy Gates|Skip Homeier|Dyke J...
# 3   Christopher Lee|Dennis Lotis|Patricia Jessel|T...
# 4   George Sanders|Barbara Shelley|Martin Stephens...
# 5   Vincent Price|Mark Damon|Myrna Fahey|Harry Ell...
# 6   Peter Cushing|Martita Hunt|Yvonne Monlaur|Fred...
# 7   Charles Herbert|Jo Morrow|Martin Milner|Rosema...
# 8   Kenneth Connor|Charles Hawtrey|Sid James|Kenne...
# 9   Albert Finney|Shirley Anne Field|Rachel Robert...
# 10  O'Shea Jackson Jr.|Corey Hawkins|Jason Mitchel...
# 11  Daniel Craig|Christoph Waltz|LÃ©a Seydoux|Ralp...
# 12  Ridley Scott|Christian Bale|Joel Edgerton|Pete...
# 13  Leonardo DiCaprio|Tom Hardy|Will Poulter|Domhn...
# 14  Akshay Kumar|Sidharth Malhotra|Jackie Shroff|J...
# 15  Samuel L. Jackson|Kurt Russell|Jennifer Jason ...
# 16  Maeve Dermody|Aidan Turner|Charles Dance|Dougl...
# 17  Robert Durst|Andrew Jarecki|Marc Smerling|Zach...
# 18  Mike Vogel|Osy Ikhile|Daisy Betts|Georgina Hai...
# 19  Oscar Isaac|Alfred Molina|Winona Ryder|Catheri...
#
#                                              homepage  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10               http://www.straightouttacompton.com/
# 11        http://www.sonypictures.com/movies/spectre/
# 12                                                NaN
# 13       http://www.foxmovies.com/movies/the-revenant
# 14  http://en.wikipedia.org/wiki/Brothers_(2015_film)
# 15                        http://thehatefuleight.com/
# 16           http://www.bbc.co.uk/programmes/b06v2v52
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                           director  \
# 0                     Roger Corman
# 1                      Jerry Lewis
# 2                  Budd Boetticher
# 3             John Llewellyn Moxey
# 4                       Wolf Rilla
# 5                     Roger Corman
# 6                   Terence Fisher
# 7                   William Castle
# 8                    Gerald Thomas
# 9                      Karel Reisz
# 10                    F. Gary Gray
# 11                      Sam Mendes
# 12            Charles de Lauzirika
# 13  Alejandro GonzÃ¡lez IÃ±Ã¡rritu
# 14                  Karan Malhotra
# 15               Quentin Tarantino
# 16                  Craig Viveiros
# 17                  Andrew Jarecki
# 18                     Nick Hurran
# 19                     Paul Haggis
#
#                                               tagline  ...  \
# 0                   The funniest picture of the year!  ...
# 1   It's a Series of Silly Sequences and One of Je...  ...
# 2            The One-Man War Against The Comancheros!  ...
# 3   300 years old! Human blood keeps them alive fo...  ...
# 4         What Demonic Force Lurks Behind Those Eyes?  ...
# 5   Edgar Allan Poe's demonic tale of The Ungodly....  ...
# 6   He Turned Innocent Beauty Into Unspeakable Hor...  ...
# 7                  IT'S FUN TO BE SCARED BY 13 GHOSTS  ...
# 8   Oh! What a Carry On When that Crazy Bunch Join...  ...
# 9   Saturday night you have your fling at life...a...  ...
# 10                                The Story of N.W.A.  ...
# 11                              A Plan No One Escapes  ...
# 12         He defied an empire and changed the world.  ...
# 13    (n. One who has returned, as if from the dead.)  ...
# 14                                Blood Against Blood  ...
# 15   No one comes up here without a damn good reason.  ...
# 16                 Agatha Christie's darkest thriller  ...
# 17  Four Decades. Three Murders. And One Very Rich...  ...
# 18                                                NaN  ...
# 19  How does a politician know he's doing the righ...  ...
#
#                                              overview runtime  \
# 0   Black comedy about a young man who creates a c...      70
# 1   Stanley is a bellboy at the Fountainbleau Hote...      72
# 2   A man saves a woman who had been kidnapped by ...      73
# 3   A young coed (Nan Barlow) uses her winter vaca...      76
# 4   In a small English village everyone suddenly f...      77
# 5   After a long journey, Philip arrives at the Us...      79
# 6   A young teacher on her way to a position in Tr...      85
# 7   Reclusive Dr. Zorba has died and left his mans...      85
# 8   With a flu epidemic running rife, three new bu...      86
# 9   Arthur, one of Britain's angry young men of th...      89
# 10  In 1987, five young men, using brutally honest...     147
# 11  A cryptic message from Bondâ€™s past sends him...     148
# 12  An in-depth documentary on the making of Ridle...     153
# 13  In the 1820s, a frontiersman, Hugh Glass, sets...     156
# 14  Brothers is an upcoming Hindi film, directed b...     156
# 15  Bounty hunters seek shelter from a raging bliz...     167
# 16  Ten strangers, drawn away from their normal li...     168
# 17  Robert Durst, scion of one of New Yorkâ€™s bil...     240
# 18  After peaceful aliens invade earth, humanity f...     246
# 19  Mayor Nick Wasicsko took office in 1987 during...     300
#
#                                      genres  \
# 0                                    Comedy
# 1                             Comedy|Family
# 2                            Action|Western
# 3                                    Horror
# 4                    Horror|Science Fiction
# 5                           Horror|Thriller
# 6                                    Horror
# 7                                    Horror
# 8                                    Comedy
# 9                                     Drama
# 10                              Drama|Music
# 11                   Action|Adventure|Crime
# 12                              Documentary
# 13         Western|Drama|Adventure|Thriller
# 14                      Family|Action|Drama
# 15              Crime|Drama|Mystery|Western
# 16                            Mystery|Drama
# 17                              Documentary
# 18  Thriller|TV Movie|Science Fiction|Drama
# 19                      History|Crime|Drama
#
#                                  production_companies release_date vote_count  \
# 0                             Santa Clara Productions      9/14/60         23
# 1          Paramount Pictures|Jerry Lewis Productions      7/20/60         12
# 2   Columbia Pictures Corporation|Ranown Pictures ...       3/1/60         12
# 3                             Vulcan Productions Inc.       9/9/60         13
# 4                           Metro-Goldwyn-Mayer (MGM)       7/1/60         28
# 5                              Alta Vista Productions      6/21/60         28
# 6   Hammer Film Productions|Hotspur Film Productio...       1/1/60         19
# 7        Columbia Pictures|William Castle Productions       8/5/60         12
# 8                            Peter Rogers Productions      2/22/60         10
# 9                           Woodfall Film Productions      8/29/60         12
# 10  New Line Cinema|Universal Pictures|Legendary P...      8/13/15        918
# 11                       Columbia Pictures|Danjaq|B24     10/26/15       3254
# 12  20th Century Fox|Lauzirika Motion Picture Company      3/17/15         14
# 13  Regency Enterprises|Appian Way|CatchPlay|Anony...     12/25/15       3929
# 14                                 Dharma Productions      8/14/15         20
# 15  Double Feature Films|The Weinstein Company|Fil...     12/25/15       2389
# 16  British Broadcasting Corporation (BBC)|Mammoth...     12/26/15         37
# 17  Blumhouse Productions|Hit the Ground Running F...       2/8/15         72
# 18                                                NaN     12/14/15         21
# 19                                                NaN      8/16/15         32
#
#     vote_average  release_year    budget_adj   revenue_adj
# 0            6.0          1960  2.211890e+05  0.000000e+00
# 1            7.0          1960  0.000000e+00  7.372967e+07
# 2            6.5          1960  0.000000e+00  0.000000e+00
# 3            6.1          1960  0.000000e+00  0.000000e+00
# 4            7.0          1960  1.474593e+06  0.000000e+00
# 5            5.9          1960  1.990701e+06  0.000000e+00
# 6            6.6          1960  0.000000e+00  0.000000e+00
# 7            5.5          1960  0.000000e+00  0.000000e+00
# 8            6.0          1960  0.000000e+00  0.000000e+00
# 9            5.6          1960  0.000000e+00  0.000000e+00
# 10           7.7          2015  2.575999e+07  1.855041e+08
# 11           6.2          2015  2.253999e+08  8.102203e+08
# 12           5.5          2015  0.000000e+00  0.000000e+00
# 13           7.2          2015  1.241999e+08  4.903142e+08
# 14           6.3          2015  0.000000e+00  0.000000e+00
# 15           7.4          2015  4.047998e+07  1.432992e+08
# 16           7.7          2015  0.000000e+00  0.000000e+00
# 17           8.4          2015  0.000000e+00  0.000000e+00
# 18           6.2          2015  0.000000e+00  0.000000e+00
# 19           7.7          2015  0.000000e+00  0.000000e+00
#
# [20 rows x 21 columns]

# %%
# Write DataFrame to CSV
vertical_stack.to_csv('out.csv', index=False)

# %%
# Place the DataFrames side by side
horizontal_stack = pd.concat([data_sub, data_sub_last10], axis=1)
horizontal_stack
# Out:
#       id    imdb_id  popularity  budget   revenue  \
# 0  24452  tt0054033    0.225218   30000         0
# 1  15788  tt0053644    0.114188       0  10000000
# 2   1673  tt0053729    0.267118       0         0
# 3  39890  tt0053719    0.065808       0         0
# 4  11773  tt0054443    0.127219  200000         0
# 5  23439  tt0053925    0.323180  270000         0
# 6  23220  tt0053677    0.333643       0         0
# 7  29756  tt0053559    0.110511       0         0
# 8  21240  tt0053699    0.136525       0         0
# 9  37230  tt0054269    0.271858       0         0
#
#                       original_title  \
# 0         The Little Shop of Horrors
# 1                        The Bellboy
# 2                   Comanche Station
# 3               The City of the Dead
# 4              Village of the Damned
# 5                     House of Usher
# 6              The Brides of Dracula
# 7                          13 Ghosts
# 8                 Carry On Constable
# 9  Saturday Night and Sunday Morning
#
#                                                 cast homepage  \
# 0  Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...      NaN
# 1  Jerry Lewis|Alex Gerry|Bob Clayton|Sonnie Sand...      NaN
# 2  Randolph Scott|Nancy Gates|Skip Homeier|Dyke J...      NaN
# 3  Christopher Lee|Dennis Lotis|Patricia Jessel|T...      NaN
# 4  George Sanders|Barbara Shelley|Martin Stephens...      NaN
# 5  Vincent Price|Mark Damon|Myrna Fahey|Harry Ell...      NaN
# 6  Peter Cushing|Martita Hunt|Yvonne Monlaur|Fred...      NaN
# 7  Charles Herbert|Jo Morrow|Martin Milner|Rosema...      NaN
# 8  Kenneth Connor|Charles Hawtrey|Sid James|Kenne...      NaN
# 9  Albert Finney|Shirley Anne Field|Rachel Robert...      NaN
#
#                director                                            tagline  \
# 0          Roger Corman                  The funniest picture of the year!
# 1           Jerry Lewis  It's a Series of Silly Sequences and One of Je...
# 2       Budd Boetticher           The One-Man War Against The Comancheros!
# 3  John Llewellyn Moxey  300 years old! Human blood keeps them alive fo...
# 4            Wolf Rilla        What Demonic Force Lurks Behind Those Eyes?
# 5          Roger Corman  Edgar Allan Poe's demonic tale of The Ungodly....
# 6        Terence Fisher  He Turned Innocent Beauty Into Unspeakable Hor...
# 7        William Castle                 IT'S FUN TO BE SCARED BY 13 GHOSTS
# 8         Gerald Thomas  Oh! What a Carry On When that Crazy Bunch Join...
# 9           Karel Reisz  Saturday night you have your fling at life...a...
#
#    ...                                           overview runtime  \
# 0  ...  In 1987, five young men, using brutally honest...     147
# 1  ...  A cryptic message from Bondâ€™s past sends him...     148
# 2  ...  An in-depth documentary on the making of Ridle...     153
# 3  ...  In the 1820s, a frontiersman, Hugh Glass, sets...     156
# 4  ...  Brothers is an upcoming Hindi film, directed b...     156
# 5  ...  Bounty hunters seek shelter from a raging bliz...     167
# 6  ...  Ten strangers, drawn away from their normal li...     168
# 7  ...  Robert Durst, scion of one of New Yorkâ€™s bil...     240
# 8  ...  After peaceful aliens invade earth, humanity f...     246
# 9  ...  Mayor Nick Wasicsko took office in 1987 during...     300
#
#                                     genres  \
# 0                              Drama|Music
# 1                   Action|Adventure|Crime
# 2                              Documentary
# 3         Western|Drama|Adventure|Thriller
# 4                      Family|Action|Drama
# 5              Crime|Drama|Mystery|Western
# 6                            Mystery|Drama
# 7                              Documentary
# 8  Thriller|TV Movie|Science Fiction|Drama
# 9                      History|Crime|Drama
#
#                                 production_companies release_date vote_count  \
# 0  New Line Cinema|Universal Pictures|Legendary P...      8/13/15        918
# 1                       Columbia Pictures|Danjaq|B24     10/26/15       3254
# 2  20th Century Fox|Lauzirika Motion Picture Company      3/17/15         14
# 3  Regency Enterprises|Appian Way|CatchPlay|Anony...     12/25/15       3929
# 4                                 Dharma Productions      8/14/15         20
# 5  Double Feature Films|The Weinstein Company|Fil...     12/25/15       2389
# 6  British Broadcasting Corporation (BBC)|Mammoth...     12/26/15         37
# 7  Blumhouse Productions|Hit the Ground Running F...       2/8/15         72
# 8                                                NaN     12/14/15         21
# 9                                                NaN      8/16/15         32
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           7.7          2015  2.575999e+07  1.855041e+08
# 1           6.2          2015  2.253999e+08  8.102203e+08
# 2           5.5          2015  0.000000e+00  0.000000e+00
# 3           7.2          2015  1.241999e+08  4.903142e+08
# 4           6.3          2015  0.000000e+00  0.000000e+00
# 5           7.4          2015  4.047998e+07  1.432992e+08
# 6           7.7          2015  0.000000e+00  0.000000e+00
# 7           8.4          2015  0.000000e+00  0.000000e+00
# 8           6.2          2015  0.000000e+00  0.000000e+00
# 9           7.7          2015  0.000000e+00  0.000000e+00
#
# [10 rows x 42 columns]

# %%
data_sub
# Out:
#       id    imdb_id  popularity  budget   revenue  \
# 0  24452  tt0054033    0.225218   30000         0
# 1  15788  tt0053644    0.114188       0  10000000
# 2   1673  tt0053729    0.267118       0         0
# 3  39890  tt0053719    0.065808       0         0
# 4  11773  tt0054443    0.127219  200000         0
# 5  23439  tt0053925    0.323180  270000         0
# 6  23220  tt0053677    0.333643       0         0
# 7  29756  tt0053559    0.110511       0         0
# 8  21240  tt0053699    0.136525       0         0
# 9  37230  tt0054269    0.271858       0         0
#
#                       original_title  \
# 0         The Little Shop of Horrors
# 1                        The Bellboy
# 2                   Comanche Station
# 3               The City of the Dead
# 4              Village of the Damned
# 5                     House of Usher
# 6              The Brides of Dracula
# 7                          13 Ghosts
# 8                 Carry On Constable
# 9  Saturday Night and Sunday Morning
#
#                                                 cast homepage  \
# 0  Jackie Joseph|Mel Welles|Jack Nicholson|Leola ...      NaN
# 1  Jerry Lewis|Alex Gerry|Bob Clayton|Sonnie Sand...      NaN
# 2  Randolph Scott|Nancy Gates|Skip Homeier|Dyke J...      NaN
# 3  Christopher Lee|Dennis Lotis|Patricia Jessel|T...      NaN
# 4  George Sanders|Barbara Shelley|Martin Stephens...      NaN
# 5  Vincent Price|Mark Damon|Myrna Fahey|Harry Ell...      NaN
# 6  Peter Cushing|Martita Hunt|Yvonne Monlaur|Fred...      NaN
# 7  Charles Herbert|Jo Morrow|Martin Milner|Rosema...      NaN
# 8  Kenneth Connor|Charles Hawtrey|Sid James|Kenne...      NaN
# 9  Albert Finney|Shirley Anne Field|Rachel Robert...      NaN
#
#                director                                            tagline  \
# 0          Roger Corman                  The funniest picture of the year!
# 1           Jerry Lewis  It's a Series of Silly Sequences and One of Je...
# 2       Budd Boetticher           The One-Man War Against The Comancheros!
# 3  John Llewellyn Moxey  300 years old! Human blood keeps them alive fo...
# 4            Wolf Rilla        What Demonic Force Lurks Behind Those Eyes?
# 5          Roger Corman  Edgar Allan Poe's demonic tale of The Ungodly....
# 6        Terence Fisher  He Turned Innocent Beauty Into Unspeakable Hor...
# 7        William Castle                 IT'S FUN TO BE SCARED BY 13 GHOSTS
# 8         Gerald Thomas  Oh! What a Carry On When that Crazy Bunch Join...
# 9           Karel Reisz  Saturday night you have your fling at life...a...
#
#    ...                                           overview runtime  \
# 0  ...  Black comedy about a young man who creates a c...      70
# 1  ...  Stanley is a bellboy at the Fountainbleau Hote...      72
# 2  ...  A man saves a woman who had been kidnapped by ...      73
# 3  ...  A young coed (Nan Barlow) uses her winter vaca...      76
# 4  ...  In a small English village everyone suddenly f...      77
# 5  ...  After a long journey, Philip arrives at the Us...      79
# 6  ...  A young teacher on her way to a position in Tr...      85
# 7  ...  Reclusive Dr. Zorba has died and left his mans...      85
# 8  ...  With a flu epidemic running rife, three new bu...      86
# 9  ...  Arthur, one of Britain's angry young men of th...      89
#
#                    genres                               production_companies  \
# 0                  Comedy                            Santa Clara Productions
# 1           Comedy|Family         Paramount Pictures|Jerry Lewis Productions
# 2          Action|Western  Columbia Pictures Corporation|Ranown Pictures ...
# 3                  Horror                            Vulcan Productions Inc.
# 4  Horror|Science Fiction                          Metro-Goldwyn-Mayer (MGM)
# 5         Horror|Thriller                             Alta Vista Productions
# 6                  Horror  Hammer Film Productions|Hotspur Film Productio...
# 7                  Horror       Columbia Pictures|William Castle Productions
# 8                  Comedy                           Peter Rogers Productions
# 9                   Drama                          Woodfall Film Productions
#
#   release_date vote_count  vote_average  release_year    budget_adj  \
# 0      9/14/60         23           6.0          1960  2.211890e+05
# 1      7/20/60         12           7.0          1960  0.000000e+00
# 2       3/1/60         12           6.5          1960  0.000000e+00
# 3       9/9/60         13           6.1          1960  0.000000e+00
# 4       7/1/60         28           7.0          1960  1.474593e+06
# 5      6/21/60         28           5.9          1960  1.990701e+06
# 6       1/1/60         19           6.6          1960  0.000000e+00
# 7       8/5/60         12           5.5          1960  0.000000e+00
# 8      2/22/60         10           6.0          1960  0.000000e+00
# 9      8/29/60         12           5.6          1960  0.000000e+00
#
#     revenue_adj
# 0  0.000000e+00
# 1  7.372967e+07
# 2  0.000000e+00
# 3  0.000000e+00
# 4  0.000000e+00
# 5  0.000000e+00
# 6  0.000000e+00
# 7  0.000000e+00
# 8  0.000000e+00
# 9  0.000000e+00
#
# [10 rows x 21 columns]

# %%
data_sub_last10
# Out:
#        id    imdb_id  popularity     budget    revenue  \
# 0  277216  tt1398426    3.202719   28000000  201634991
# 1  206647  tt2379713    6.200282  245000000  880674609
# 2  333873  tt4426954    0.197788          0          0
# 3  281957  tt1663202    9.110700  135000000  532950503
# 4  330037  tt3802576    0.099678          0          0
# 5  273248  tt3460252    5.898400   44000000  155760117
# 6  371758  tt3581932    0.112284          0          0
# 7  321640  tt4299972    0.033378          0          0
# 8  373977  tt4146128    0.031635          0          0
# 9  340968  tt2492296    0.249595          0          0
#
#                                       original_title  \
# 0                             Straight Outta Compton
# 1                                            Spectre
# 2  Keepers of the Covenant: Making Exodus: Gods a...
# 3                                       The Revenant
# 4                                           Brothers
# 5                                  The Hateful Eight
# 6                           And Then There Were None
# 7      The Jinx: The Life and Deaths of Robert Durst
# 8                                    Childhood's End
# 9                                     Show Me a Hero
#
#                                                 cast  \
# 0  O'Shea Jackson Jr.|Corey Hawkins|Jason Mitchel...
# 1  Daniel Craig|Christoph Waltz|LÃ©a Seydoux|Ralp...
# 2  Ridley Scott|Christian Bale|Joel Edgerton|Pete...
# 3  Leonardo DiCaprio|Tom Hardy|Will Poulter|Domhn...
# 4  Akshay Kumar|Sidharth Malhotra|Jackie Shroff|J...
# 5  Samuel L. Jackson|Kurt Russell|Jennifer Jason ...
# 6  Maeve Dermody|Aidan Turner|Charles Dance|Dougl...
# 7  Robert Durst|Andrew Jarecki|Marc Smerling|Zach...
# 8  Mike Vogel|Osy Ikhile|Daisy Betts|Georgina Hai...
# 9  Oscar Isaac|Alfred Molina|Winona Ryder|Catheri...
#
#                                             homepage  \
# 0               http://www.straightouttacompton.com/
# 1        http://www.sonypictures.com/movies/spectre/
# 2                                                NaN
# 3       http://www.foxmovies.com/movies/the-revenant
# 4  http://en.wikipedia.org/wiki/Brothers_(2015_film)
# 5                        http://thehatefuleight.com/
# 6           http://www.bbc.co.uk/programmes/b06v2v52
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                          director  \
# 0                    F. Gary Gray
# 1                      Sam Mendes
# 2            Charles de Lauzirika
# 3  Alejandro GonzÃ¡lez IÃ±Ã¡rritu
# 4                  Karan Malhotra
# 5               Quentin Tarantino
# 6                  Craig Viveiros
# 7                  Andrew Jarecki
# 8                     Nick Hurran
# 9                     Paul Haggis
#
#                                              tagline  ...  \
# 0                                The Story of N.W.A.  ...
# 1                              A Plan No One Escapes  ...
# 2         He defied an empire and changed the world.  ...
# 3    (n. One who has returned, as if from the dead.)  ...
# 4                                Blood Against Blood  ...
# 5   No one comes up here without a damn good reason.  ...
# 6                 Agatha Christie's darkest thriller  ...
# 7  Four Decades. Three Murders. And One Very Rich...  ...
# 8                                                NaN  ...
# 9  How does a politician know he's doing the righ...  ...
#
#                                             overview runtime  \
# 0  In 1987, five young men, using brutally honest...     147
# 1  A cryptic message from Bondâ€™s past sends him...     148
# 2  An in-depth documentary on the making of Ridle...     153
# 3  In the 1820s, a frontiersman, Hugh Glass, sets...     156
# 4  Brothers is an upcoming Hindi film, directed b...     156
# 5  Bounty hunters seek shelter from a raging bliz...     167
# 6  Ten strangers, drawn away from their normal li...     168
# 7  Robert Durst, scion of one of New Yorkâ€™s bil...     240
# 8  After peaceful aliens invade earth, humanity f...     246
# 9  Mayor Nick Wasicsko took office in 1987 during...     300
#
#                                     genres  \
# 0                              Drama|Music
# 1                   Action|Adventure|Crime
# 2                              Documentary
# 3         Western|Drama|Adventure|Thriller
# 4                      Family|Action|Drama
# 5              Crime|Drama|Mystery|Western
# 6                            Mystery|Drama
# 7                              Documentary
# 8  Thriller|TV Movie|Science Fiction|Drama
# 9                      History|Crime|Drama
#
#                                 production_companies release_date vote_count  \
# 0  New Line Cinema|Universal Pictures|Legendary P...      8/13/15        918
# 1                       Columbia Pictures|Danjaq|B24     10/26/15       3254
# 2  20th Century Fox|Lauzirika Motion Picture Company      3/17/15         14
# 3  Regency Enterprises|Appian Way|CatchPlay|Anony...     12/25/15       3929
# 4                                 Dharma Productions      8/14/15         20
# 5  Double Feature Films|The Weinstein Company|Fil...     12/25/15       2389
# 6  British Broadcasting Corporation (BBC)|Mammoth...     12/26/15         37
# 7  Blumhouse Productions|Hit the Ground Running F...       2/8/15         72
# 8                                                NaN     12/14/15         21
# 9                                                NaN      8/16/15         32
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           7.7          2015  2.575999e+07  1.855041e+08
# 1           6.2          2015  2.253999e+08  8.102203e+08
# 2           5.5          2015  0.000000e+00  0.000000e+00
# 3           7.2          2015  1.241999e+08  4.903142e+08
# 4           6.3          2015  0.000000e+00  0.000000e+00
# 5           7.4          2015  4.047998e+07  1.432992e+08
# 6           7.7          2015  0.000000e+00  0.000000e+00
# 7           8.4          2015  0.000000e+00  0.000000e+00
# 8           6.2          2015  0.000000e+00  0.000000e+00
# 9           7.7          2015  0.000000e+00  0.000000e+00
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Joining DataFrames

# %% [markdown]
# When we concatenated our DataFrames, we simply added them to each other - stacking them either vertically or side by side. Another way to combine DataFrames is to use columns in each dataset that contain common values (a common unique identifier).
#
# The columns containing the common values are called “join key(s)”. Joining DataFrames in this way is often useful when one DataFrame is a “lookup table” containing additional data that we want to include in the other.

# %% [markdown]
# ### Import multiple data files

# %% [markdown]
# Many functions in Python have a set of options that can be set by the user if needed. Let's tell pandas to assign empty values in our CSV to NaN with the parameters `keep_default_na=False` and `na_values=[""]`.

# %%
movies = pd.read_csv("movies.csv",
                   keep_default_na=False,
                   na_values=[""])

movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.read_csv("ratings.csv",
                   keep_default_na=False,
                   na_values=[""])

ratings
# Out:
#        userId  movieId  rating   timestamp
# 0           1        1     4.0   964982703
# 1           1        3     4.0   964981247
# 2           1        6     4.0   964982224
# 3           1       47     5.0   964983815
# 4           1       50     5.0   964982931
# ...       ...      ...     ...         ...
# 50903     610   166534     4.0  1493848402
# 50904     610   168248     5.0  1493850091
# 50905     610   168250     5.0  1494273047
# 50906     610   168252     5.0  1493846352
# 50907     610   170875     3.0  1493846415
#
# [50908 rows x 4 columns]

# %% [markdown]
# ### Identifying join keys

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %% [markdown]
# In our example, the join key is the `movieId` column.

# %% [markdown]
# ### Types of joins
#
# #### Inner join
# - Returns a new DataFrame that contains only those rows that have matching values in both of the original DataFrames.
# - `merged_inner = pd.merge(left=df1, right=df2, left_on='col1', right_on='col2')`
#
# #### Left join
# - Returns all of the rows from the left DataFrame, even those rows whose join key(s) do not have values in the right DataFrame.
# - `merged_left = pd.merge(left=df1, right=df2, how='left', left_on='col1', right_on='col2')`
#
# #### Right join
# - Returns all of the rows from the right DataFrame, even those rows whose join key(s) do not have values in the left DataFrame.
# - `merged_right = pd.merge(left=df1, right=df2, how='right', left_on='col1', right_on='col2')`
#
# #### Full (outer) join
# - Returns all pairwise combinations of rows from both DataFrames.
# - `merged_outer = pd.merge(left=df1, right=df2, how='outer', left_on='col1', right_on='col2')`

# %%
# Inner join

# Option 1
merged_inner = pd.merge(left=movies, right=ratings, left_on='movieId', right_on='movieId')

# Option 2
merged_inner = pd.merge(left=movies, right=ratings, on='movieId')

merged_inner
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            1                                   Toy Story (1995)
# 2            1                                   Toy Story (1995)
# 3            1                                   Toy Story (1995)
# 4            1                                   Toy Story (1995)
# ...        ...                                                ...
# 50903   190209                 Jeff Ross Roasts the Border (2017)
# 50904   190213                                   John From (2015)
# 50905   190215                                Liquid Truth (2017)
# 50906   190219                                       Bunny (1998)
# 50907   190221  Hommage à Zgougou (et salut à Sabine Mamou) (2...
#
#                                             genres  userId  rating   timestamp
# 0      Adventure|Animation|Children|Comedy|Fantasy       1     4.0   964982703
# 1      Adventure|Animation|Children|Comedy|Fantasy       5     4.0   847434962
# 2      Adventure|Animation|Children|Comedy|Fantasy      15     2.5  1510577970
# 3      Adventure|Animation|Children|Comedy|Fantasy     334     3.5  1225477466
# 4      Adventure|Animation|Children|Comedy|Fantasy     336     4.0  1122227329
# ...                                            ...     ...     ...         ...
# 50903                                       Comedy     338     4.0  1530148487
# 50904                                        Drama     338     1.0  1530148478
# 50905                                        Drama     338     1.5  1530148477
# 50906                                    Animation     338     1.0  1530148473
# 50907                                  Documentary     338     1.0  1530148473
#
# [50908 rows x 6 columns]

# %%
# Left join
merged_left = pd.merge(left=movies, right=ratings, on='movieId', how='left')
merged_left
# Out:
#        movieId                                      title  \
# 0            1                           Toy Story (1995)
# 1            1                           Toy Story (1995)
# 2            1                           Toy Story (1995)
# 3            1                           Toy Story (1995)
# 4            1                           Toy Story (1995)
# ...        ...                                        ...
# 52480   193581  Black Butler: Book of the Atlantic (2017)
# 52481   193583               No Game No Life: Zero (2017)
# 52482   193585                               Flint (2017)
# 52483   193587        Bungo Stray Dogs: Dead Apple (2018)
# 52484   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                             genres  userId  rating  \
# 0      Adventure|Animation|Children|Comedy|Fantasy     1.0     4.0
# 1      Adventure|Animation|Children|Comedy|Fantasy     5.0     4.0
# 2      Adventure|Animation|Children|Comedy|Fantasy    15.0     2.5
# 3      Adventure|Animation|Children|Comedy|Fantasy   334.0     3.5
# 4      Adventure|Animation|Children|Comedy|Fantasy   336.0     4.0
# ...                                            ...     ...     ...
# 52480              Action|Animation|Comedy|Fantasy     NaN     NaN
# 52481                     Animation|Comedy|Fantasy     NaN     NaN
# 52482                                        Drama     NaN     NaN
# 52483                             Action|Animation     NaN     NaN
# 52484                                       Comedy     NaN     NaN
#
#           timestamp
# 0      9.649827e+08
# 1      8.474350e+08
# 2      1.510578e+09
# 3      1.225477e+09
# 4      1.122227e+09
# ...             ...
# 52480           NaN
# 52481           NaN
# 52482           NaN
# 52483           NaN
# 52484           NaN
#
# [52485 rows x 6 columns]

# %%
# Right join
merged_right = pd.merge(left=movies, right=ratings, on='movieId', how='right')
merged_right
# Out:
#        movieId                           title  \
# 0            1                Toy Story (1995)
# 1            3         Grumpier Old Men (1995)
# 2            6                     Heat (1995)
# 3           47     Seven (a.k.a. Se7en) (1995)
# 4           50      Usual Suspects, The (1995)
# ...        ...                             ...
# 50903   166534                    Split (2017)
# 50904   168248   John Wick: Chapter Two (2017)
# 50905   168250                  Get Out (2017)
# 50906   168252                    Logan (2017)
# 50907   170875  The Fate of the Furious (2017)
#
#                                             genres  userId  rating   timestamp
# 0      Adventure|Animation|Children|Comedy|Fantasy       1     4.0   964982703
# 1                                   Comedy|Romance       1     4.0   964981247
# 2                            Action|Crime|Thriller       1     4.0   964982224
# 3                                 Mystery|Thriller       1     5.0   964983815
# 4                           Crime|Mystery|Thriller       1     5.0   964982931
# ...                                            ...     ...     ...         ...
# 50903                        Drama|Horror|Thriller     610     4.0  1493848402
# 50904                        Action|Crime|Thriller     610     5.0  1493850091
# 50905                                       Horror     610     5.0  1494273047
# 50906                                Action|Sci-Fi     610     5.0  1493846352
# 50907                  Action|Crime|Drama|Thriller     610     3.0  1493846415
#
# [50908 rows x 6 columns]

# %%
# Full (outer) join
merged_outer = pd.merge(left=movies, right=ratings, on='movieId', how='outer')
merged_outer
# Out:
#        movieId                                      title  \
# 0            1                           Toy Story (1995)
# 1            1                           Toy Story (1995)
# 2            1                           Toy Story (1995)
# 3            1                           Toy Story (1995)
# 4            1                           Toy Story (1995)
# ...        ...                                        ...
# 52480   193581  Black Butler: Book of the Atlantic (2017)
# 52481   193583               No Game No Life: Zero (2017)
# 52482   193585                               Flint (2017)
# 52483   193587        Bungo Stray Dogs: Dead Apple (2018)
# 52484   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                             genres  userId  rating  \
# 0      Adventure|Animation|Children|Comedy|Fantasy     1.0     4.0
# 1      Adventure|Animation|Children|Comedy|Fantasy     5.0     4.0
# 2      Adventure|Animation|Children|Comedy|Fantasy    15.0     2.5
# 3      Adventure|Animation|Children|Comedy|Fantasy   334.0     3.5
# 4      Adventure|Animation|Children|Comedy|Fantasy   336.0     4.0
# ...                                            ...     ...     ...
# 52480              Action|Animation|Comedy|Fantasy     NaN     NaN
# 52481                     Animation|Comedy|Fantasy     NaN     NaN
# 52482                                        Drama     NaN     NaN
# 52483                             Action|Animation     NaN     NaN
# 52484                                       Comedy     NaN     NaN
#
#           timestamp
# 0      9.649827e+08
# 1      8.474350e+08
# 2      1.510578e+09
# 3      1.225477e+09
# 4      1.122227e+09
# ...             ...
# 52480           NaN
# 52481           NaN
# 52482           NaN
# 52483           NaN
# 52484           NaN
#
# [52485 rows x 6 columns]

# %% [markdown]
# ------------------------------------------------------
# # SLIDES
# ------------------------------------------------------

# %% [markdown]
# # Introduction to Plotting

# %% [markdown]
# Let's create a copy of our `merged_inner` data and make some plots with that.

# %%
data_complete = merged_inner.copy()

# %%
# Plot data directly from a Pandas dataframe
data_complete['rating'].plot(kind='hist')
plt.title('Distribution of Movie Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.hist(data_complete['rating'], bins=5, color='skyblue', edgecolor='black')
plt.title('Distribution of Movie Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')

# Save the plot before showing it
plt.savefig('matplotlib_histogram.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# Seaborn
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.histplot(data_complete['rating'], bins=5, color='skyblue', kde=False)
plt.title('Distribution of Movie Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')

# Save the plot before showing it
plt.savefig('seaborn_histogram.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# Plotnine
from plotnine import ggplot, aes, geom_histogram, ggtitle, labs, theme_classic

plot = (ggplot(data_complete, aes(x='rating')) +
        geom_histogram(bins=5, fill='skyblue', color='black') +
        ggtitle('Distribution of Movie Ratings') +
        labs(x='Rating', y='Frequency') +
        theme_classic())
        
plot.show()
# Save the plot
plot.save('plotnine_histogram.png', dpi=300)
# Out:
# /Users/lizetgomez/Code/tutorial/.venv/lib/python3.10/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/lizetgomez/Code/tutorial/.venv/lib/python3.10/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: plotnine_histogram.png

# %% [markdown]
# These examples provide the same output visually but differ significantly in the way they are coded. The choice between them depends on the user's preference for customization, simplicity, and familiarity with the plotting paradigm.
#
# #### Summary of Differences
#
# **Matplotlib:**
#
# - Requires more boilerplate code (e.g., `plt.figure()`, `plt.show()`).
# - Customisation (color, labels) is done through method arguments.
# - The histogram is created using `plt.hist()`.
#
# **Seaborn:**
#
# - Less code than Matplotlib, with some additional aesthetics by default.
# - Histogram created with `sns.histplot()`; `kde=False` disables the kernel density estimate line.
# - Integrates with Matplotlib for underlying plotting but adds simplicity.
#
# **Plotnine:**
#
# - Follows a declarative style with the *Grammar of Graphics* approach.
# - Plots are constructed by layering components (`ggplot`, `aes`, `geom_histogram`).
# - Requires fewer explicit function calls for titles and labels but uses a more complex syntax.

# %% [markdown]
# ------------------------------------------------------
# # SLIDES
# ------------------------------------------------------
