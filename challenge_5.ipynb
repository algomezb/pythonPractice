# %% [markdown]
# # Summary data

# %%
import pandas as pd
# Note: Update the relative path to the data
my_data = pd.read_csv("tmdb-movies.csv")
grouped_data = my_data.groupby('release_year')

# %% [markdown]
# 1. How many movies were released per year?

# %%
import matplotlib.pyplot as plt
grouped_data.describe()['id']['count'].plot()
# Out:
# <Axes: xlabel='release_year'>

# %%
my_data.groupby(['release_year', 'director']).agg({"budget": 'max',
                                                  "runtime": 'median',
                                                  "revenue": 'mean'})
# Out:
#                                 budget  runtime     revenue
# release_year director
# 1960         Alfred Hitchcock   806948    109.0  32000000.0
#              Billy Wilder      3000000    125.0  25000000.0
#              Budd Boetticher         0     73.0         0.0
#              David Miller            0    110.0         0.0
#              David Swift             0    134.0         0.0
# ...                                ...      ...         ...
# 2015         Yorgos Lanthimos  4000000    118.0   9064511.0
#              Zach Lipovsky           0    118.0         0.0
#              Zachary Sluser          0     95.0         0.0
#              Zackary Adler     2500000    110.0         0.0
#              Zeke Norton             0     74.0         0.0
#
# [10488 rows x 3 columns]

# %% [markdown]
# 2. What happens when you group by two columns using the following syntax and then calculate mean values?

# %%
grouped_data2 = my_data.groupby(['release_year', 'director'])
grouped_data2.mean(numeric_only=True)
# Out:
#                                      id  popularity     budget     revenue  \
# release_year director
# 1960         Alfred Hitchcock     539.0    2.610362   806948.0  32000000.0
#              Billy Wilder         284.0    0.947307  3000000.0  25000000.0
#              Budd Boetticher     1673.0    0.267118        0.0         0.0
#              David Miller       12617.0    0.232574        0.0         0.0
#              David Swift        31102.0    0.254124        0.0         0.0
# ...                                 ...         ...        ...         ...
# 2015         Yorgos Lanthimos  254320.0    2.885126  4000000.0   9064511.0
#              Zach Lipovsky     293771.0    0.459597        0.0         0.0
#              Zachary Sluser    291189.0    0.246609        0.0         0.0
#              Zackary Adler     356216.0    0.199570  2500000.0         0.0
#              Zeke Norton       316322.0    0.714131        0.0         0.0
#
#                                runtime  vote_count  vote_average  \
# release_year director
# 1960         Alfred Hitchcock    109.0      1180.0           8.0
#              Billy Wilder        125.0       235.0           7.9
#              Budd Boetticher      73.0        12.0           6.5
#              David Miller        110.0        10.0           5.7
#              David Swift         134.0        25.0           7.2
# ...                                ...         ...           ...
# 2015         Yorgos Lanthimos    118.0       638.0           6.6
#              Zach Lipovsky       118.0        82.0           4.9
#              Zachary Sluser       95.0        12.0           5.0
#              Zackary Adler       110.0        11.0           4.7
#              Zeke Norton          74.0        13.0           5.5
#
#                                  budget_adj   revenue_adj
# release_year director
# 1960         Alfred Hitchcock  5.949601e+06  2.359350e+08
#              Billy Wilder      2.211890e+07  1.843242e+08
#              Budd Boetticher   0.000000e+00  0.000000e+00
#              David Miller      0.000000e+00  0.000000e+00
#              David Swift       0.000000e+00  0.000000e+00
# ...                                     ...           ...
# 2015         Yorgos Lanthimos  3.679998e+06  8.339346e+06
#              Zach Lipovsky     0.000000e+00  0.000000e+00
#              Zachary Sluser    0.000000e+00  0.000000e+00
#              Zackary Adler     2.299999e+06  0.000000e+00
#              Zeke Norton       0.000000e+00  0.000000e+00
#
# [10488 rows x 9 columns]

# %% [markdown]
# 3. Summarize revenue values for each year in your data. HINT: you can use the following syntax to only create summary statistics for one column in your data. `my_data['release_year'].describe()`

# %%
my_data['release_year'].describe()
# Out:
# count    10825.000000
# mean      2001.320554
# std         12.814274
# min       1960.000000
# 25%       1995.000000
# 50%       2006.000000
# 75%       2011.000000
# max       2015.000000
# Name: release_year, dtype: float64
